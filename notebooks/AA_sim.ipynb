# %% [markdown]
# If running in Google Colab, you will need to put your downloaded simulation folder into Neural-Modeling/simulations/

# %%
import sys
sys.path.append('..')
sys.path.append('../Modules')

import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
print(os.getcwd())
if 'notebook' in os.getcwd():
    # os.chdir("../scripts") # go from Neural-Modeling/notebooks to Neural-Modeling/scripts, where simulation outputs will be generated to. (maybe a separate folder could be used...)
    os.chdir("../simulations") # go to output folder
    print(os.getcwd())
# Out:
# /home/drfrbc/Neural-Modeling/notebooks
# /home/drfrbc/Neural-Modeling/simulations

# %%
sim_dir = '/home/drfrbc/Neural-Modeling/simulations/2025-06-09-13-55-no_clustering_30sec_sta/complex'

sim_dir = '/home/drfrbc/Neural-Modeling/simulations/2025-06-09-13-55-no_clustering_30sec_sta_same_fr/complex'

sim_dir = "/home/drfrbc/Neural-Modeling/simulations/2025-06-10-12-28-tuft_clustering_30sec_sta_lower_oblique_exc_dens/complex"

sim_dir = '/home/drfrbc/Neural-Modeling/simulations/2025-06-10-14-33-tuft_clustering_30sec_sta_lower_oblique_exc_dens_less/complex'

sim_dir = '/home/drfrbc/Neural-Modeling/simulations/2025-06-11-13-55-no_clustering_30sec_sta_same_fr_lower_oblique_exc_dens_less/complex'

sim_dir = '/home/drfrbc/Neural-Modeling/simulations/2025-06-10-18-18-tuft_clustering_30sec_sta_inc_tuft_exc_dens/complex'

sim_dir = '/home/drfrbc/Neural-Modeling/simulations/2025-06-10-18-19-no_clustering_30sec_sta_inc_tuft_exc_dens/complex' # was same as before?

sim_dir = '/home/drfrbc/Neural-Modeling/simulations/2025-06-10-18-20-no_clustering_30sec_sta_inc_tuft_exc_dens_not_same_fr/complex'
 
sim_dir = '/home/drfrbc/Neural-Modeling/simulations/2025-06-11-11-20-tuft_clustering_30sec_sta_inc_tuft_exc_dens_more/complex'

sim_dir = '/home/drfrbc/Neural-Modeling/simulations/2025-06-12-12-46-testing_modulations/complex'

sim_dir = '/home/drfrbc/Neural-Modeling/simulations/2025-06-12-12-55-testing_modulations/complex' # longer duration

sim_dir = '/home/drfrbc/Neural-Modeling/simulations/2025-06-12-13-40-pink_and_delay_no_clustering/complex' # not actually no clustering

sim_dir = '/home/drfrbc/Neural-Modeling/simulations/2025-06-12-14-09-pink_and_delay_no_clustering/complex' # no clustering

sim_dir = '/home/drfrbc/Neural-Modeling/simulations/2025-06-12-16-00-pink_and_delay_no_clustering_fix_bgs/complex' # no clustering fix delay modulation

sim_dir = '/home/drfrbc/Neural-Modeling/simulations/2025-06-12-16-29-check_pink_and_delay_no_clustering_fix_bgs/complex'

sim_dir = '/home/drfrbc/Neural-Modeling/simulations/2025-06-26-13-07-check_loc_dep_synapses/complex'

sim_dir = '/home/drfrbc/Neural-Modeling/simulations/2025-06-30-12-17-check_loc_dep_synapses/complex'

sim_dir = '/home/drfrbc/Neural-Modeling/simulations/2025-06-30-14-01-check_loc_dep_synapses/complex'

sim_dir = '/home/drfrbc/Neural-Modeling/simulations/2025-06-30-15-04-check_loc_dep_synapses/complex'

sim_dir = '/home/drfrbc/Neural-Modeling/simulations/2025-07-01-09-59-high_baseline_fr/complex'

sim_dir = '/home/drfrbc/Neural-Modeling/simulations/2025-07-01-11-30-high_baseline_fr/complex'

sim_dir = '/home/drfrbc/Neural-Modeling/simulations/2025-07-01-13-10-high_baseline_fr/complex'

sim_dir = '/home/drfrbc/Neural-Modeling/simulations/2025-07-01-15-30-high_baseline_fr/complex'

sim_dir = '/home/drfrbc/Neural-Modeling/simulations/2025-07-02-13-11-local_L5_weaker_correlated_more_pcs/complex'

sim_dir = '/home/drfrbc/Neural-Modeling/simulations/2025-07-02-13-17-local_L5_higher_correlated_more_pcs/complex'

sim_dir = '/home/drfrbc/Neural-Modeling/simulations/2025-07-02-13-58-local_L5_higher_correlated_more_pcs/complex'

sim_dir = '/home/drfrbc/Neural-Modeling/simulations/2025-07-02-14-36-local_L5_higher_correlated_more_pcs_add_var_in_syns_per_pc/complex'

sim_dir = '/home/drfrbc/Neural-Modeling/simulations/2025-07-03-09-38-increase_basal_syn_dens/complex'

sim_dir = '/home/drfrbc/Neural-Modeling/simulations/2025-07-03-13-51-increase_basal_syn_dens/complex'

sim_dir = '/home/drfrbc/Neural-Modeling/simulations/2025-07-03-14-38-increase_basal_syn_dens/complex'

sim_dir = '/home/drfrbc/Neural-Modeling/simulations/2025-07-03-15-27-increase_basal_syn_dens/complex'
sim_dir = '/home/drfrbc/Neural-Modeling/simulations/2025-07-03-16-53-increase_basal_syn_dens/complex'

sim_dir = '/home/drfrbc/Neural-Modeling/simulations/2025-07-07-09-52-reduce_perisom_inh_fr/complex'
sim_dir = '/home/drfrbc/Neural-Modeling/simulations/2025-07-07-10-35-reduce_perisom_inh_fr/complex'
sim_dir = '/home/drfrbc/Neural-Modeling/simulations/2025-07-07-11-42-reduce_perisom_inh_fr/complex'

sim_dir = '/home/drfrbc/Neural-Modeling/simulations/2025-07-07-12-18-reduce_perisom_inh_fr/complex'

sim_dir = '/home/drfrbc/Neural-Modeling/simulations/2025-07-07-13-01-reduce_perisom_inh_fr/complex'

sim_dir = '/home/drfrbc/Neural-Modeling/simulations/2025-07-07-15-19-reduce_perisom_inh_fr/complex'

sim_dir = '/home/drfrbc/Neural-Modeling/simulations/2025-07-07-16-34-reduce_perisom_inh_fr/complex'

sim_dir = '/home/drfrbc/Neural-Modeling/simulations/2025-07-08-09-20-rhythmic_inh/complex'

sim_dir = '/home/drfrbc/Neural-Modeling/simulations/2025-07-08-09-28-rhythmic_inh_test_full_depth/complex'

sim_dir = '/home/drfrbc/Neural-Modeling/simulations/2025-07-08-10-54-rhythmic_inh_test_full_depth_0.05/complex'

sim_dir = '/home/drfrbc/Neural-Modeling/simulations/2025-07-08-14-36-delay_and_rhythmic_0.15/complex'

sim_dir = '/home/drfrbc/Neural-Modeling/simulations/2025-07-08-15-15-delay_and_rhythmic_0.15/complex'

sim_dir = '/home/drfrbc/Neural-Modeling/simulations/2025-07-09-14-09-delay_and_rhythmic_0.15/complex'

sim_dir = '/home/drfrbc/Neural-Modeling/simulations/2025-07-10-12-22-delay_and_rhythmic_0.15/complex'

sim_dir = '/home/drfrbc/Neural-Modeling/simulations/2025-07-10-13-39-delay_and_rhythmic_0.15/complex'

sim_dir = '/home/drfrbc/Neural-Modeling/simulations/2025-07-10-14-40-delay_and_rhythmic_0.15/complex'

sim_dir = '/home/drfrbc/Neural-Modeling/simulations/2025-07-10-15-52-halve_oblique_density/complex'

sim_dir = '/home/drfrbc/Neural-Modeling/simulations/2025-07-21-09-22-depth_0.15/complex'

# %%
import Modules.analysis as analysis
parameters = analysis.DataReader.load_parameters(sim_dir)
# Out:
# ...
# --No graphics will be displayed.

# %%
parameters.h_tstop
# Out:
# 10000

# %% [markdown]
# ## Read simulation folder to build cell with synapses.

# %%
from Modules.synapses_file import PreSimSynapseGenerator #TODO: rename synapses_file to something else
pssg = PreSimSynapseGenerator(sim_dir)
cell = pssg.build_synapses_onto_cell_obj() # TODO: Implement run on all simulations within sims_dir
# Out:
# NEURON: The user defined name already exists: AMPA_NMDA
#  near line 0
#  }
#   ^
#         nrn_load_dll("../scripts...")
# Removing duplicate coordinate at index 1 in section L5PCtemplate[0].apic[0]

# %% [markdown]
# ## Simulate

# %%
from Modules.simulation_slurm import Simulation
from Modules.cell_builder import SkeletonCell
from Modules.logger import Logger

sim = Simulation(getattr(SkeletonCell, parameters.skeleton_cell_type), create_dir = False) #TODO: clean up implementation. Probably creating extra folder. # create_dir is a quick fix to prevent creating a new sim_dir (based on skeleton_cell) since we are using a sim_dir that already exists.
#TODO: Prevent Simulation from creating a new sim_dir if one already exists. (path using skeleton_cell)
#TODO: move builder_runtime.txt and replace_runtime.txt to sim_dir and to runtimes.csv
sim.path = os.path.split(sim_dir)[0] #simulator.sims_dir
sim.logger = Logger(sim_dir)

sim.run_single_simulation(parameters=parameters, cell=cell)

# %%
# from Modules.synapse_analysis import SynapseAnalyzer

# # Initialize the analyzer with your simulation directory
# synapse_analyzer = SynapseAnalyzer(sim_dir)
# synapse_analyzer.add_segment_data()

# # plot the synapse clusters
# synapse_analyzer.plot_all_synapse_clusters(
#     plot_both_together=True,
#     plot_each_type_separately=True
# )
