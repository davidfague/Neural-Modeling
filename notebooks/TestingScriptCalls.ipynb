# %%
is_colab = 'google.colab' in str(get_ipython())
if is_colab:
    # !pip install neuron
    # !git clone https://github.com/davidfague/Neural-Modeling.git -b cleanup
    # %cd Neural-Modeling/scripts
    # !pip install neuron_reduce
    # !pip install ipympl

# %%
import sys
sys.path.append("../")
sys.path.append("../Modules/")

from Modules.simulation import Simulation
from Modules.cell_builder import SkeletonCell, CellBuilder
from Modules.constants import HayParameters

import os
from neuron import h

from logger import Logger # type: ignore

import numpy as np
# Out:
# Warning: no DISPLAY environment variable.
# --No graphics will be displayed.

# %%
# %cd ../scripts
# Out:
# /home/drfrbc/Neural-Modeling/scripts
# /home/drfrbc/miniconda3/envs/sim_env/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
try:
    os.system("rm -r x86_64/")
except:
    pass

# %%
#Plot Passive FI
import os
import numpy as np

# Define the template for common attributes
common_attributes = {
    'h_tstop': 2000,
    'all_synapses_off': True,
    'CI_on': True,
    'h_i_duration': 1950,
    'h_i_delay': 50
}

# Define the varying attributes for each sim_name, without including 'sim_name' key
varying_attributes = [
    {'base_sim_name': 'Complex', 'reduce_cell_selective': False},
    {'base_sim_name': 'Basals', 'reduce_basals': True},
    {'base_sim_name': 'Tufts', 'reduce_tufts': True},
    {'base_sim_name': 'Obliques', 'reduce_obliques': True},
    {'base_sim_name': 'All', 'reduce_obliques': True, 'reduce_tufts': True, 'reduce_basals': True}
]

# Generate the list of HayParameters with updated sim_names
all_parameters = [
    HayParameters(
        **common_attributes,
        h_i_amplitude=round(amp, 1),
        sim_name=f"{attributes['base_sim_name']}_amp_{round(amp, 1)}",
        **{k: v for k, v in attributes.items() if k != 'base_sim_name'}
    )
    for amp in np.arange(-2, 2.1, 0.2)
    for attributes in varying_attributes
]

# Initialize simulation
sim = Simulation(SkeletonCell.Hay, title='FI_Passive')

# Submit jobs to simulation
for parameters in all_parameters:
    sim.submit_job(parameters)

# Remove directory if it exists
try:
    os.system("rm -r x86_64/")
except:
    pass

# Run the simulation
sim.run()

# Create directory for saving results
output_dir = f"../notebooks/{sim.title}"
os.makedirs(output_dir, exist_ok=True)

# Get all parameter paths
all_parameters_paths = [parameters.path for parameters in all_parameters]

# Plot results and save to the directory
plot_command = f"python3 plot_fi.py -d {sim.path} -s {output_dir}"
os.system(plot_command)

# Optional: create individual directories for each parameter set and plot separately
# for parameters in all_parameters:
#     sim_name_dir = f"../notebooks/FI_Passive/{parameters.sim_name}"
#     os.makedirs(sim_name_dir, exist_ok=True)
#     plot_command = f"python3 plot_fi.py -d {parameters.path} -s {sim_name_dir}"
#     os.system(plot_command)
# Out:
# (2024-05-21 13:19:26.676733)-[PID: 399754]–[INFO]: Total number of jobs: 105
# (2024-05-21 13:19:26.677016)-[PID: 399754]–[INFO]: Total number of proccessors: 192
# (2024-05-21 13:19:26.677070)-[PID: 399754]–[INFO]: Compiling modfiles.
# rm: cannot remove 'x86_64/': No such file or directory
# (2024-05-21 13:19:27.742146)-[PID: 400069]–[INFO]: Building SkeletonCell.Hay.(2024-05-21 13:19:27.742016)-[PID: 400068]–[INFO]: Building SkeletonCell.Hay.(2024-05-21 13:19:27.742768)-[PID: 400070]–[INFO]: Building SkeletonCell.Hay.(2024-05-21 13:19:27.743520)-[PID: 400071]–[INFO]: Building SkeletonCell.Hay.
#
#
#
# (2024-05-21 13:19:27.744285)-[PID: 400072]–[INFO]: Building SkeletonCell.Hay.(2024-05-21 13:19
# There is no segment to segment copy, it means that some segments in thereduced model did not receive channels from the original cell.Trying to compensate by copying channels from neighboring segments
# (2024-05-21 13:19:39.840785)-[PID: 400138]–[INFO]: Saving data at step: 10000
# (2024-05-21 13:19:39.873646)-[PID: 400164]–[INFO]: Saving data at step: 10000
# (2024-05-21 13:19:39.876660)-[PID: 400138]–[INFO]: Finished writing data
# (2024-05-21 13:19:39.878667)-[PID: 400138]–[INFO]: Finished clearing recorders
# (2024-05-21 13:19:39.899831)-[PID: 400148]–[INFO]: Saving data at step: 10000
# (2024-05-21 13:19:39.903389)-[PID: 400075]–[INFO]: Starting simulation.
# (2024-05-21 13:19:39.909158)-[PID: 400164]–[INFO]: Finished writing data
# (2024-05-21 13:19:39.911278)-[PID: 400164]–[INFO]: Finished clearing recorders
# (2024-05-21 13:19:39.922465)-[PID: 400169]–[INFO]: Saving data at step: 10000
# (2024-05-21 13:19:39.939693)-[PID: 400148]–[INFO]: Finished writing data
# (2024-05-21 13:19:39.941929)-[PID: 400148]–[INFO]: Finished clearing recorders
# (2024-05-21 13:19:39.955162)-[PID: 400143]–[INFO]: Saving data at step: 10000
# (2024-05-21 13:19:39.958516)-[PID: 400169]–[INFO]: Finished writing data
# (2024-05-21 13:19:39.960739)-[PID: 400169]–[INFO]: Finished clearing recorders
# (2024-05-21 13:19:39.991283)-[PID: 400143]–[INFO]: Finished writing data
# (2024-05-21 13:19:39.993653)-[PID: 400143]–[INFO]: Finished clearing recorders
# (2024-05-21 13:19:40.014607)-[PID: 400154]–[INFO]: Saving data at step: 10000
# (2024-05-21 13:19:40.050475)-[PID: 400154]–[INFO]: Finished writing data
# (2024-05-21 13:19:40.052856)-[PID: 400154]–[INFO]: Finished clearing recorders
# (2024-05-21 13:19:40.348864)-[PID: 400113]–[INFO]: Saving data at step: 10000
# (2024-05-21 13:19:40.376853)-[PID: 400068]–[INFO]: Saving data at step: 10000
# (2024-05-21 13:19:40.389202)-[PID: 400113]–[INFO]: Finished writing data
# (2024-05-21 13:19:40.391768)-[PID: 400113]–[INFO]: Finished clearing recorders
# (2024-05-21 13:19:40.412899)-[PID: 400068]–[INFO]: Finished writing data(2024-05-21 13:19:40.413464)-[PID: 400090]–[INFO]: Finished creating a CellModel object.
#
# (2024-05-21 13:19:40.415103)-[PID: 400090]–[INFO]: Finish building in 12.64946985244751(2024-05-21 13:19:40.415215)-[PID: 400068]–[INFO]: Finished clearing recorders
#
# (2024-05-21 13:19:40.419139)-[PID: 400100]–[INFO]: Starting simulation.
# (2024-05-21 13:19:40.650546)-[PID: 400073]–[INFO]: Saving data at step: 10000
# (2024-05-21 13:19:40.687421)-[PID: 400073]–[INFO]: Finished writing data
# (2024-05-21 13:19:40.689708)-[PID: 400073]–[INFO]: Finished clearing recorders
# (2024-05-21 13:19:40.832148)-[PID: 400098]–[INFO]: Saving data at step: 10000
# (2024-05-21 13:19:40.868215)-[PID: 400098]–[INFO]: Finished writing data
# (2024-05-21 13:19:40.870587)-[PID: 400098]–[INFO]: Finished clearing recorders
# (2024-05-21 13:19:40.886267)-[PID: 400123]–[INFO]: Saving data at step: 10000
# (2024-05-21 13:19:40.922571)-[PID: 400123]–[INFO]: Finished writing data
# (2024-05-21 13:19:40.924916)-[PID: 400123]–[INFO]: Finished clearing recorders
# There is no segment to segment copy, it means that some segments in thereduced model did not receive channels from the original cell.Trying to compensate by copying channels from neighboring segments
# (2024-05-21 13:19:41.051185)-[PID: 400145]–[INFO]: Finished creating a CellModel object.
# (2024-05-21 13:19:41.053542)-[PID: 400145]–[INFO]: Finish building in 13.099658489227295
# (2024-05-21 13:19:41.106191)-[PID: 400085]–[INFO]: Starting simulation.
# There is no segment to segment copy, it means that some segments in thereduced model did not receive channels from the original cell.Trying to compensate by copying channels from neighboring segments
# (2024-05-21 13:19:41.170280)-[PID: 400120]–[INFO]: Starting simulation.
# (2024-05-21 13:19:41.232711)-[PID: 400078]–[INFO]: Saving data at step: 10000
# (2024-05-21 13:19:41.269004)-[PID: 400078]–[INFO]: Finished writing data
# (2024-05-21 13:19:41.271399)-[PID: 400078]–[INFO]: Finished clearing recorders
# (2024-05-21 13:19:41.373556)-[PID: 400128]–[INFO]: Saving data at step: 10000
# (2024-05-21 13:19:41.409909)-[PID: 400128]–[INFO]: Finished writing data
# (2024-05-21 13:19:41.412183)-[PID: 400128]–[INFO]: Finished clearing recorders
# (2024-05-21 13:19:41.483828)-[PID: 400070]–[INFO]: Starting simulation.
# (2024-05-21 13:19:41.543720)-[PID: 400093]–[INFO]: Saving data at step: 10000
# (2024-05-21 13:19:41.564670)-[PID: 400088]–[INFO]: Saving data at step: 10000
# (2024-05-21 13:19:41.579500)-[PID: 400093]–[INFO]: Finished writing data
# (2024-05-21 13:19:41.581819)-[PID: 400093]–[INFO]: Finished clearing recorders
# (2024-05-21 13:19:41.602282)-[PID: 400088]–[INFO]: Finished writing data
# (2024-05-21 13:19:41.604575)-[PID: 400088]–[INFO]: Finished clearing recorders
# (2024-05-21 13:19:41.663045)-[PID: 400103]–[INFO]: Saving data at step: 10000
# (2024-05-21 13:19
# There is no segment to segment copy, it means that some segments in thereduced model did not receive channels from the original cell.Trying to compensate by copying channels from neighboring segments
# (2024-05-21 13:19:44.699748)-[PID: 400101]–[INFO]: Finished creating a CellModel object.
# (2024-05-21 13:19:44.701758)-[PID: 400101]–[INFO]: Finish building in 16.91771674156189
# (2024-05-21 13:19:44.713513)-[PID: 400074]–[INFO]: Finished creating a CellModel object.
# ...
# (2024-05-21 13:19:54.651103)-[PID: 400144]–[INFO]: Saving data at step: 20000
# (2024-05-21 13:19:54.655573)-[PID: 400117]–[INFO]: Saving data at step: 20000
# (2024-05-21 13:19:54.667731)-[PID: 400117]–[INFO]: Finished writing data
# (2024-05-21 13:19:54.669269)-[PID: 400117]–[INFO]: Finished clearing recorders
# (2024-05-21 13:19:54.669802)-[PID: 400165]–[INFO]: Finished writing data
# (2024-05-21 13:19:54.671616)-[PID: 400165]–[INFO]: Finished clearing recorders
# (2024-05-21 13:19:54.672108)-[PID: 400117]–[INFO]: Finish simulation in 2.712 seconds
# (2024-05-21 13:19:54.675119)-[PID: 400144]–[INFO]: Finished writing data
# (2024-05-21 13:19:54.676595)-[PID: 400165]–[INFO]: Finish simulation in 6.861 seconds(2024-05-21 13:19:54.676755)-[PID: 400144]–[INFO]: Finished clearing recorders
#
# (2024-05-21 13:19:54.682048)-[PID: 400144]–[INFO]: Finish simulation in 6.967 seconds
# (2024-05-21 13:19:54.757411)-[PID: 400107]–[INFO]: Saving data at step: 20000
# (2024-05-21 13:19:54.768883)-[PID: 400107]–[INFO]: Finished writing data
# (2024-05-21 13:19:54.770334)-[PID: 400107]–[INFO]: Finished clearing recorders
# (2024-05-21 13:19:54.772915)-[PID: 400107]–[INFO]: Finish simulation in 2.693 seconds
# (2024-05-21 13:19:54.896939)-[PID: 400102]–[INFO]: Saving data at step: 20000
# (2024-05-21 13:19:54.907924)-[PID: 400102]–[INFO]: Finished writing data
# (2024-05-21 13:19:54.909268)-[PID: 400102]–[INFO]: Finished clearing recorders
# (2024-05-21 13:19:54.912079)-[PID: 400102]–[INFO]: Finish simulation in 2.703 seconds
# (2024-05-21 13:19:54.961905)-[PID: 400089]–[INFO]: Saving data at step: 20000
# (2024-05-21 13:19:54.984093)-[PID: 400089]–[INFO]: Finished writing data
# (2024-05-21 13:19:54.985793)-[PID: 400089]–[INFO]: Finished clearing recorders
# (2024-05-21 13:19:54.990918)-[PID: 400089]–[INFO]: Finish simulation in 7.026 seconds
# (2024-05-21 13:19:55.058671)-[PID: 400069]–[INFO]: Saving data at step: 20000
# (2024-05-21 13:19:55.066202)-[PID: 400114]–[INFO]: Saving data at step: 20000
# (2024-05-21 13:19:55.082294)-[PID: 400069]–[INFO]: Finished writing data
# (2024-05-21 13:19:55.084123)-[PID: 400069]–[INFO]: Finished clearing recorders
# (2024-05-21 13:19:55.088635)-[PID: 400114]–[INFO]: Finished writing data(2024-05-21 13:19:55.088902)-[PID: 400069]–[INFO]: Finish simulation in 6.655 seconds
#
# (2024-05-21 13:19:55.089794)-[PID: 400081]–[INFO]: Starting simulation.(2024-05-21 13:19:55.090380)-[PID: 400114]–[INFO]: Finished clearing recorders
# (2024-05-21 13:19:55.090497)-[PID: 400071]–[INFO]: Starting simulation.
#
# (2024-05-21 13:19:55.095325)-[PID: 400114]–[INFO]: Finish simulation in 6.938 seconds
# (2024-05-21 13:19:55.109137)-[PID: 400145]–[INFO]: Saving data at step: 20000
# (2024-05-21 13:19:55.134925)-[PID: 400145]–[INFO]: Finished writing data
# (2024-05-21 13:19:55.136812)-[PID: 400145]–[INFO]: Finished clearing recorders
# (2024-05-21 13:19:55.142689)-[PID: 400145]–[INFO]: Finish simulation in 8.035 seconds
# (2024-05-21 13:19:55.264942)-[PID: 400119]–[INFO]: Saving data at step: 20000
# (2024-05-21 13:19:55.287712)-[PID: 400119]–[INFO]: Finished writing data
# (2024-05-21 13:19:55.289496)-[PID: 400119]–[INFO]: Finished clearing recorders
# (2024-05-21 13:19:55.294317)-[PID: 400119]–[INFO]: Finish simulation in 6.585 seconds
# (2024-05-21 13:19:55.364732)-[PID: 400092]–[INFO]: Saving data at step: 20000
# (2024-05-21 13:19:55.376150)-[PID: 400092]–[INFO]: Finished writing data
# (2024-05-21 13:19:55.377676)-[PID: 400092]–[INFO]: Finished clearing recorders
# (2024-05-21 13:19:55.380369)-[PID: 400092]–[INFO]: Finish simulation in 2.607 seconds
# (2024-05-21 13:19:55.383929)-[PID: 400074]–[INFO]: Saving data at step: 20000
# (2024-05-21 13:19:55.406623)-[PID: 400074]–[INFO]: Finished writing data
# (2024-05-21 13:19:55.408394)-[PID: 400074]–[INFO]: Finished clearing recorders
# (2024-05-21 13:19:55.413762)-[PID: 400074]–[INFO]: Finish simulation in 7.000 seconds
# (2024-05-21 13:19:55.555439)-[PID: 400112]–[INFO]: Saving data at step: 10000
# (2024-05-21 13:19:55.566893)-[PID: 400112]–[INFO]: Finished writing data
# (2024-05-21 13:19:55.568261)-[PID: 400112]–[INFO]: Finished clearing recorders
# (2024-05-21 13:19:55.598050)-[PID: 400099]–[INFO]: Saving data at step: 20000
# (2024-05-21 13:19:55.620597)-[PID: 400099]–[INFO]: Finished writing data
# (2024-05-21 13:19:55.622312)-[PID: 400099]–[INFO]: Finished clearing recorders
# (2024-05-21 13:19:55.627184)-[PID: 400099]–[INFO]: Finish simulation in 6.651 seconds
# (2024-05-21 13:19:55.754403)-[PID: 400158]–[INFO]: Saving data at step: 10000
# (2024-05-21 13:19:55.766342)-[PID: 400158]–[INFO]: Finished writing data
# (2024-05-21 13:19:55.767696)-[PID: 400158]–[INFO]: Finished clearing recorders
# (2024-05-21 13:19:55.814115)-[PID: 400131]–[INFO]: Saving data at step: 20000
# (2024-05-21 13:19:55.840476)-[PID: 400131]–[INFO]: Finished writing data
# (2024-05-21 13:19:55.842298)-[PID: 400131]–[INFO]: Finished clearing recorders
# (2024-05-21 13:19:55.848033)-[PID: 400131]–[INFO]: Finish simulation in 8.331 seconds
# (2024-05-21 13:19:56.027977)-[PID: 400162]–[INFO]: Saving data at step: 20000
# (2024-05-21 13:19:56.030221)-[PID: 400079]–[INFO]: Saving data at step: 20000
# (2024-05-21 13:19:56.034012)-[PID: 400086]–[INFO]: Saving data at step: 20000
# (2024-05-21 13:19:56.053035)-[PID: 400079]–[INFO]: Finished writing data
# (2024-05-21 13:19:56.054775)-[PID: 400079]–[INFO]: Finished clearing recorders
# (2024-05-21 13:19:56.056246)-[PID: 400162]–[INFO]: Finished writing data
# (2024-05-21 13:19:56.058227)-[PID: 400162]–[INFO]: Finished clearing recorders
# (2024-05-21 13:19:56.059937)-[PID: 400079]–[INFO]: Finish simulation in 6.826 seconds
# (2024-05-21 13:19:56.060303)-[PID: 400126]–[INFO]: Saving data at step: 20000
# (2024-05-21 13:19:56.062565)-[PID: 400086]–[INFO]: Finished writing data
# (2024-05-21 13:19:56.064358)-[PID: 400162]–[INFO]: Finish simulation in 8.457 seconds(2024-05-21 13:19:56.064328)-[PID: 400086]–[INFO]: Finished clearing recorders
#
# (2024-05-21 13:19:56.070917)-[PID: 400086]–[INFO]: Finish simulation in 8.611 seconds
# (2024-05-21 13:19:56.086390)-[PID: 400126]–[INFO]: Finished writing data
# (2024-05-21 13:19:56.088176)-[PID: 400126]–[INFO]: Finished clearing recorders
# (2024-05-21 13:19:56.093636)-[PID: 400126]–[INFO]: Finish simulation in 8.195 seconds
# (2024-05-21 13:19:56.104727)-[PID: 400167]–[INFO]: Saving data at step: 20000
# (2024-05-21 13:19:56.131662)-[PID: 400167]–[INFO]: Finished writing data
# (2024-05-21 13:19:56.133655)-[PID: 400167]–[INFO]: Finished clearing recorders
# (2024-05-21 13:19:56.139499)-[PID: 400167]–[INFO]: Finish simulation in 8.497 seconds
# (2024-05-21 13:19:56.164128)-[PID: 400076]–[INFO]: Saving data at step: 20000
# (2024-05-21 13:19:56.178378)-[PID: 400172]–[INFO]: Saving data at step: 20000(2024-05-21 13:19:56.178356)-[PID: 400152]–[INFO]: Saving data at step: 20000
#
# (2024-05-21 13:19:56.191005)-[PID: 400076]–[INFO]: Finished writing data
# (2024-05-21 13:19:56.192869)-[PID: 400076]–[INFO]: Finished clearing recorders
# (2024-05-21 13:19:56.198721)-[PID: 400076]–[INFO]: Finish simulation in 8.645 seconds
# (2024-05-21 13:19:56.206912)-[PID: 400152]–[INFO]: Finished writing data(2024-05-21 13:19:56.206914)-[PID: 400172]–[INFO]: Finished writing data
#
# (2024-05-21 13:19:56.208781)-[PID: 400172]–[INFO]: Finished clearing recorders(2024-05-21 13:19:56.208929)-[PID: 400152]–[INFO]: Finished clearing recorders
#
# (2024-05-21 13:19:56.209745)-[PID: 400149]–[INFO]: Saving data at step: 20000
# (2024-05-21 13:19:56.215031)-[PID: 400172]–[INFO]: Finish simulation in 8.480 seconds(2024-05-21 13:19:56.215258)-[PID: 400152]–[INFO]: Finish simulation in 8.561 seconds
#
# (2024-05-21 13:19:56.231980)-[PID: 400149]–[INFO]: Finished writing data
# (2024-05-21 13:19:56.233601)-[PID: 400149]–[INFO]: Finished clearing recorders
# (2024-05-21 13:19:56.238298)-[PID: 400149]–[INFO]: Finish simulation in 6.726 seconds
# (2024-05-21 13:19:56.245063)-[PID: 400146]–[INFO]: Saving data at step: 20000
# (2024-05-21 13:19:56.271956)-[PID: 400146]–[INFO]: Finished writing data
# (2024-05-21 13:19:56.273765)-[PID: 400146]–[INFO]: Finished clearing recorders
# (2024-05-21 13:19:56.279636)-[PID: 400146]–[INFO]: Finish simulation in 8.610 seconds
# (2024-05-21 13:19:56.341101)-[PID: 400121]–[INFO]: Saving data at step: 20000
# (2024-05-21 13:19:56.367393)-[PID: 400121]–[INFO]: Finished writing data
# (2024-05-21 13:19:56.369127)-[PID: 400121]–[INFO]: Finished clearing recorders
# (2024-05-21 13:19:56.374678)-[PID: 400121]–[INFO]: Finish simulation in 8.630 seconds
# (2024-05-21 13:19:56.387206)-[PID: 400157]–[INFO]: Saving data at step: 20000
# (2024-05-21 13:19:56.413446)-[PID: 400157]–[INFO]: Finished writing data
# (2024-05-21 13:19:56.415287)-[PID: 400157]–[INFO]: Finished clearing recorders
# (2024-05-21 13:19:56.421134)-[PID: 400157]–[INFO]: Finish simulation in 8.591 seconds
# (2024-05-21 13:19:56.527273)-[PID: 400134]–[INFO]: Saving data at step: 20000
# (2024-05-21 13:19:56.545160)-[PID: 400116]–[INFO]: Saving data at step: 20000
# (2024-05-21 13:19:56.548399)-[PID: 400134]–[INFO]: Finished writing data
# (2024-05-21 13:19:56.549948)-[PID: 400134]–[INFO]: Finished clearing recorders
# (2024-05-21 13:19:56.554541)-[PID: 400134]–[INFO]: Finish simulation in 6.584 seconds
# (2024-05-21 13:19:56.572379)-[PID: 400116]–[INFO]: Finished writing data
# (2024-05-21 13:19:56.574097)-[PID: 400116]–[INFO]: Finished clearing recorders
# (2024-05-21 13:19:56.579791)-[PID: 400116]–[INFO]: Finish simulation in 8.640 seconds
# (2024-05-21 13:19:56.604219)-[PID: 400094]–[INFO]: Saving data at step: 20000
# (2024-05-21 13:19:56.625414)-[PID: 400111]–[INFO]: Saving data at step: 20000
# (2024-05-21 13:19:56.626687)-[PID: 400094]–[INFO]: Finished writing data
# (2024-05-21 13:19:56.628363)-[PID: 400094]–[INFO]: Finished clearing recorders
# (2024-05-21 13:19:56.633168)-[PID: 400094]–[INFO]: Finish simulation in 6.678 seconds
# (2024-05-21 13:19:56.651152)-[PID: 400111]–[INFO]: Finished writing data
# (2024-05-21 13:19:56.652888)-[PID: 400111]–[INFO]: Finished clearing recorders
# (2024-05-21 13:19:56.658550)-[PID: 400111]–[INFO]: Finish simulation in 8.566 seconds
# (2024-05-21 13:19:56.664114)-[PID: 400141]–[INFO]: Saving data at step: 20000
# (2024-05-21 13:19:56.689893)-[PID: 400141]–[INFO]: Finished writing data
# (2024-05-21 13:19:56.691798)-[PID: 400141]–[INFO]: Finished clearing recorders
# (2024-05-21 13:19:56.697324)-[PID: 400141]–[INFO]: Finish simulation in 8.331 seconds
# (2024-05-21 13:19:56.806560)-[PID: 400112]–[INFO]: Saving data at step: 20000
# (2024-05-21 13:19:56.817154)-[PID: 400112]–[INFO]: Finished writing data
# (2024-05-21 13:19:56.818362)-[PID: 400112]–[INFO]: Finished clearing recorders
# (2024-05-21 13:19:56.821027)-[PID: 400112]–[INFO]: Finish simulation in 2.564 seconds
# (2024-05-21 13:19:56.838381)-[PID: 400104]–[INFO]: Saving data at step: 20000
# (2024-05-21 13:19:56.860933)-[PID: 400104]–[INFO]: Finished writing data
# (2024-05-21 13:19:56.862546)-[PID: 400104]–[INFO]: Finished clearing recorders
# (2024-05-21 13:19:56.866961)-[PID: 400106]–[INFO]: Saving data at step: 20000(2024-05-21 13:19:56.867184)-[PID: 400104]–[INFO]: Finish simulation in 6.494 seconds
#
# (2024-05-21 13:19:56.891882)-[PID: 400106]–[INFO]: Finished writing data
# (2024-05-21 13:19:56.893551)-[PID: 400106]–[INFO]: Finished clearing recorders
# (2024-05-21 13:19:56.899147)-[PID: 400106]–[INFO]: Finish simulation in 8.562 seconds
# (2024-05-21 13:19:57.022737)-[PID: 400158]–[INFO]: Saving data at step: 20000
# (2024-05-21 13:19:57.033395)-[PID: 400158]–[INFO]: Finished writing data
# (2024-05-21 13:19:57.034561)-[PID: 400158]–[INFO]: Finished clearing recorders
# (2024-05-21 13:19:57.037110)-[PID: 400158]–[INFO]: Finish simulation in 2.577 seconds
# (2024-05-21 13:19:57.041764)-[PID: 400084]–[INFO]: Saving data at step: 20000
# (2024-05-21 13:19:57.063284)-[PID: 400084]–[INFO]: Finished writing data
# (2024-05-21 13:19:57.065040)-[PID: 400084]–[INFO]: Finished clearing recorders
# (2024-05-21 13:19:57.069721)-[PID: 400084]–[INFO]: Finish simulation in 6.562 seconds
# (2024-05-21 13:19:57.136088)-[PID: 400109]–[INFO]: Saving data at step: 10000
# (2024-05-21 13:19:57.155332)-[PID: 400096]–[INFO]: Saving data at step: 20000
# (2024-05-21 13:19:57.159361)-[PID: 400109]–[INFO]: Finished writing data
# (2024-05-21 13:19:57.161109)-[PID: 400109]–[INFO]: Finished clearing recorders
# (2024-05-21 13:19:57.170941)-[PID: 400129]–[INFO]: Saving data at step: 10000
# (2024-05-21 13:19:57.180969)-[PID: 400096]–[INFO]: Finished writing data
# (2024-05-21 13:19:57.182654)-[PID: 400096]–[INFO]: Finished clearing recorders
# (2024-05-21 13:19:57.188506)-[PID: 400096]–[INFO]: Finish simulation in 8.560 seconds
# (2024-05-21 13:19:57.193089)-[PID: 400129]–[INFO]: Finished writing data
# (2024-05-21 13:19:57.194557)-[PID: 400129]–[INFO]: Finished clearing recorders
# (2024-05-21 13:19:57.481130)-[PID: 400101]–[INFO]: Saving data at step: 20000
# (2024-05-21 13:19:57.506622)-[PID: 400101]–[INFO]: Finished writing data
# (2024-05-21 13:19:57.508400)-[PID: 400101]–[INFO]: Finished clearing recorders
# (2024-05-21 13:19:57.513760)-[PID: 400101]–[INFO]: Finish simulation in 8.309 seconds
# (2024-05-21 13:19:57.539047)-[PID: 400136]–[INFO]: Saving data at step: 20000
# (2024-05-21 13:19:57.567668)-[PID: 400136]–[INFO]: Finished writing data
# (2024-05-21 13:19:57.569644)-[PID: 400136]–[INFO]: Finished clearing recorders
# (2024-05-21 13:19:57.575130)-[PID: 400136]–[INFO]: Finish simulation in 8.223 seconds
# (2024-05-21 13:19:57.606958)-[PID: 400091]–[INFO]: Saving data at step: 20000
# (2024-05-21 13:19:57.631352)-[PID: 400091]–[INFO]: Finished writing data
# (2024-05-21 13:19:57.633148)-[PID: 400091]–[INFO]: Finished clearing recorders
# (2024-05-21 13:19:57.638880)-[PID: 400091]–[INFO]: Finish simulation in 8.382 seconds
# (2024-05-21 13:19:57.726370)-[PID: 400155]–[INFO]: Saving data at step: 20000
# (2024-05-21 13:19:57.747697)-[PID: 400155]–[INFO]: Finished writing data
# (2024-05-21 13:19:57.749391)-[PID: 400155]–[INFO]: Finished clearing recorders
# (2024-05-21 13:19:57.753921)-[PID: 400155]–[INFO]: Finish simulation in 6.495 seconds
# (2024-05-21 13:19:59.018465)-[PID: 400081]–[INFO]: Saving data at step: 10000
# (2024-05-21 13:19:59.039788)-[PID: 400071]–[INFO]: Saving data at step: 10000
# (2024-05-21 13:19:59.045805)-[PID: 400081]–[INFO]: Finished writing data
# (2024-05-21 13:19:59.047426)-[PID: 400081]–[INFO]: Finished clearing recorders
# (2024-05-21 13:19:59.071736)-[PID: 400071]–[INFO]: Finished writing data
# (2024-05-21 13:19:59.073670)-[PID: 400071]–[INFO]: Finished clearing recorders
# (2024-05-21 13:20:00.085523)-[PID: 400109]–[INFO]: Saving data at step: 20000
# (2024-05-21 13:20:00.107581)-[PID: 400109]–[INFO]: Finished writing data
# (2024-05-21 13:20:00.109358)-[PID: 400109]–[INFO]: Finished clearing recorders
# (2024-05-21 13:20:00.114129)-[PID: 400109]–[INFO]: Finish simulation in 6.179 seconds
# (2024-05-21 13:20:00.119636)-[PID: 400129]–[INFO]: Saving data at step: 20000
# (2024-05-21 13:20:00.141175)-[PID: 400129]–[INFO]: Finished writing data
# (2024-05-21 13:20:00.142716)-[PID: 400129]–[INFO]: Finished clearing recorders
# (2024-05-21 13:20:00.147188)-[PID: 400129]–[INFO]: Finish simulation in 6.178 seconds
# (2024-05-21 13:20:02.708975)-[PID: 400081]–[INFO]: Saving data at step: 20000
# (2024-05-21 13:20:02.735145)-[PID: 400081]–[INFO]: Finished writing data
# (2024-05-21 13:20:02.736911)-[PID: 400081]–[INFO]: Finished clearing recorders
# (2024-05-21 13:20:02.742490)-[PID: 400081]–[INFO]: Finish simulation in 7.651 seconds
# (2024-05-21 13:20:02.778586)-[PID: 400071]–[INFO]: Saving data at step: 20000
# (2024-05-21 13:20:02.807720)-[PID: 400071]–[INFO]: Finished writing data
# (2024-05-21 13:20:02.809626)-[PID: 400071]–[INFO]: Finished clearing recorders
# (2024-05-21 13:20:02.815529)-[PID: 400071]–[INFO]: Finish simulation in 7.724 seconds
# Collecting FI curves data for Complex
# Warning: no DISPLAY environment variable.
# --No graphics will be displayed.
# Collecting FI curves data for Basals
# Collecting FI curves data for Tufts
# Collecting FI curves data for Obliques
# Collecting FI curves data for All
# Figure(600x600)
# 0

# %%
# LFP

# Define the template for common attributes
common_attributes = {
    'h_tstop': 1000,
    'record_ecp': True
}

# Define the varying attributes for each sim_name, without including 'sim_name' key
varying_attributes = [
    {'base_sim_name': 'Complex', 'reduce_cell_selective': False},
    {'base_sim_name': 'Basals', 'reduce_basals': True},
    {'base_sim_name': 'Tufts', 'reduce_tufts': True},
    {'base_sim_name': 'Obliques', 'reduce_obliques': True},
    {'base_sim_name': 'All', 'reduce_obliques': True, 'reduce_tufts': True, 'reduce_basals': True}
]

# Generate the list of HayParameters with updated sim_names
all_parameters = [
    HayParameters(
        **common_attributes,
        sim_name=attributes['base_sim_name'],
        **{k: v for k, v in attributes.items() if k != 'base_sim_name'}
    )
    for attributes in varying_attributes
]

# Initialize simulation
sim = Simulation(SkeletonCell.Hay, title='LFP')

# Submit jobs to simulation
for parameters in all_parameters:
    sim.submit_job(parameters)

# Remove directory if it exists
try:
    os.system("rm -r x86_64/")
except Exception as e:
    print(f"Error while removing directory: {e}")

# Run the simulation
sim.run()

# Create directory for saving results
output_dir = f"../notebooks/LFP/{sim.title}"
os.makedirs(output_dir, exist_ok=True)

# Plot results for each parameter set and save to individual directories
for parameters in all_parameters:
    sim_name_dir = f"{output_dir}/{parameters.sim_name}"
    os.makedirs(sim_name_dir, exist_ok=True)
    plot_command = f"python3 plot_lfp.py -d {parameters.path} -s {sim_name_dir}"
    os.system(plot_command)

# Placeholder for future enhancements
# Example: Compute correlations between LFP heatmaps
# def compute_correlations(parameter_paths):
#     # Logic to compute and plot correlations
#     pass

# all_parameter_paths = [parameters.path for parameters in all_parameters]
# compute_correlations(all_parameter_paths)
# Out:
# rm: cannot remove 'x86_64/': No such file or directory
# (2024-05-21 13:20:04.145066)-[PID: 399754]–[INFO]: Total number of jobs: 5
# (2024-05-21 13:20:04.145210)-[PID: 399754]–[INFO]: Total number of proccessors: 192
# (2024-05-21 13:20:04.145305)-[PID: 399754]–[INFO]: Compiling modfiles.
# (2024-05-21 13:20:04.735300)-[PID: 405703]–[INFO]: Building SkeletonCell.Hay.(2024-05-21 13:20:04.735300)-[PID: 405704]–[INFO]: Building SkeletonCell.Hay.(2024-05-21 13
–[INFO]: Finished creating a CellModel object.
# (2024-05-21 13:22:48.474643)-[PID: 405705]–[INFO]: Finish building in 163.74010586738586
# There is no segment to segment copy, it means that some segments in thereduced model did not receive channels from the original cell.Trying to compensate by copying channels from neighboring segments
# (2024-05-21 13:22:54.310784)-[PID: 405704]–[WARNING]: Recording ECP adds the extracellular channel to all segments after computing electrotonic distance.                                      This channel is therefore not accounted for in impedence calculation, but it might affect the simulation.
# (2024-05-21 13:22:54.783680)-[PID: 405704]–[INFO]: Starting simulation.
# (2024-05-21 13:22:57.094450)-[PID: 405705]–[WARNING]: Recording ECP adds the extracellular channel to all segments after computing electrotonic distance.                                      This channel is therefore not accounted for in impedence calculation, but it might affect the simulation.
# (2024-05-21 13:22:57.571788)-[PID: 405705]–[INFO]: Starting simulation.
# (2024-05-21 13:22:59.574541)-[PID: 405703]–[INFO]: Finished creating a CellModel object.
# (2024-05-21 13:22:59.576099)-[PID: 405703]–[INFO]: Finish building in 174.84173369407654
# (2024-05-21 13:23:06.593309)-[PID: 405703]–[WARNING]: Recording ECP adds the extracellular channel to all segments after computing electrotonic distance.                                      This channel is therefore not accounted for in impedence calculation, but it might affect the simulation.
# (2024-05-21 13:23:06.987654)-[PID: 405703]–[INFO]: Starting simulation.
# (2024-05-21 13:23:09.765756)-[PID: 405702]–[INFO]: Saving data at step: 10000
# (2024-05-21 13:23:09.829458)-[PID: 405702]–[INFO]: Finished writing data
# (2024-05-21 13:23:09.832105)-[PID: 405702]–[INFO]: Finished clearing recorders
# (2024-05-21 13:23:09.885865)-[PID: 405702]–[INFO]: Finish simulation in 41.050 seconds
# (2024-05-21 13:23:32.735324)-[PID: 405704]–[INFO]: Saving data at step: 10000
# (2024-05-21 13:23:32.781177)-[PID: 405704]–[INFO]: Finished writing data
# (2024-05-21 13:23:32.783597)-[PID: 405704]–[INFO]: Finished clearing recorders
# (2024-05-21 13:23:32.832218)-[PID: 405704]–[INFO]: Finish simulation in 38.047 seconds
# (2024-05-21 13:23:36.609100)-[PID: 405705]–[INFO]: Saving data at step: 10000
# (2024-05-21 13:23:36.656500)-[PID: 405705]–[INFO]: Finished writing data
# (2024-05-21 13:23:36.658964)-[PID: 405705]–[INFO]: Finished clearing recorders
# (2024-05-21 13:23:36.709187)-[PID: 405705]–[INFO]: Finish simulation in 39.136 seconds
# (2024-05-21 13:23:43.257757)-[PID: 405706]–[INFO]: Finished creating a CellModel object.
# (2024-05-21 13:23:43.259955)-[PID: 405706]–[INFO]: Finish building in 218.52537655830383
# (2024-05-21 13:23:44.969824)-[PID: 405703]–[INFO]: Saving data at step: 10000
# (2024-05-21 13:23:45.010515)-[PID: 405703]–[INFO]: Finished writing data
# (2024-05-21 13:23:45.012786)-[PID: 405703]–[INFO]: Finished clearing recorders
# (2024-05-21 13:23:45.061780)-[PID: 405703]–[INFO]: Finish simulation in 38.073 seconds
# (2024-05-21 13:23:45.895775)-[PID: 405706]–[WARNING]: Recording ECP adds the extracellular channel to all segments after computing electrotonic distance.                                      This channel is therefore not accounted for in impedence calculation, but it might affect the simulation.
# (2024-05-21 13:23:46.021507)-[PID: 405706]–[INFO]: Starting simulation.
# (2024-05-21 13:24:22.105392)-[PID: 405706]–[INFO]: Saving data at step: 10000
# (2024-05-21 13:24:22.125693)-[PID: 405706]–[INFO]: Finished writing data
# (2024-05-21 13:24:22.127423)-[PID: 405706]–[INFO]: Finished clearing recorders
# (2024-05-21 13:24:22.172844)-[PID: 405706]–[INFO]: Finish simulation in 36.150 seconds
# Warning: no DISPLAY environment variable.
# --No graphics will be displayed.
# morph['pc']: {morph['pc']}
# morph['dl']: {morph['dl']}
# Warning: no DISPLAY environment variable.
# --No graphics will be displayed.
# morph['pc']: {morph['pc']}
# morph['dl']: {morph['dl']}
# Warning: no DISPLAY environment variable.
# --No graphics will be displayed.
# morph['pc']: {morph['pc']}
# morph['dl']: {morph['dl']}
# Warning: no DISPLAY environment variable.
# --No graphics will be displayed.
# morph['pc']: {morph['pc']}
# morph['dl']: {morph['dl']}
# Warning: no DISPLAY environment variable.
# --No graphics will be displayed.
# morph['pc']: {morph['pc']}
# morph['dl']: {morph['dl']}

# %%
# plot FI with synapses
import os
import numpy as np

# Define the template for common attributes
common_attributes = {
    'h_tstop': 2000,
    'all_synapses_off': False,
    'CI_on': True,
    'h_i_duration': 1950,
    'h_i_delay': 50
}

# Define the varying attributes for each sim_name, without including 'sim_name' key
varying_attributes = [
    {'base_sim_name': 'Complex', 'reduce_cell_selective': False},
    {'base_sim_name': 'Basals', 'reduce_basals': True},
    {'base_sim_name': 'Tufts', 'reduce_tufts': True},
    {'base_sim_name': 'Obliques', 'reduce_obliques': True},
    {'base_sim_name': 'All', 'reduce_obliques': True, 'reduce_tufts': True, 'reduce_basals': True}
]

# Generate the list of HayParameters with updated sim_names
all_parameters = [
    HayParameters(
        **common_attributes,
        h_i_amplitude=round(amp, 1),
        sim_name=f"{attributes['base_sim_name']}_amp_{round(amp, 1)}",
        **{k: v for k, v in attributes.items() if k != 'base_sim_name'}
    )
    for amp in np.arange(-2, 2.1, 0.2)
    for attributes in varying_attributes
]

# Initialize simulation
sim = Simulation(SkeletonCell.Hay, title='FI_Synapses')

# Submit jobs to simulation
for parameters in all_parameters:
    sim.submit_job(parameters)

# Remove directory if it exists
try:
    os.system("rm -r x86_64/")
except:
    pass

# Run the simulation
sim.run()

# Create directory for saving results
output_dir = f"../notebooks/{sim.title}"
os.makedirs(output_dir, exist_ok=True)

# Get all parameter paths
all_parameters_paths = [parameters.path for parameters in all_parameters]

# Plot results and save to the directory
plot_command = f"python3 plot_fi.py -d {sim.path} -s {output_dir}"
os.system(plot_command)
# Out:
# rm: cannot remove 'x86_64/': No such file or directory
# (2024-05-21 13:24:31.161981)-[PID: 399754]–[INFO]: Total number of jobs: 105
# (2024-05-21 13:24:31.162251)-[PID: 399754]–[INFO]: Total number of proccessors: 192
# (2024-05-21 13:24:31.162322)-[PID: 399754]–[INFO]: Compiling modfiles.
# (2024-05-21 13:24:32.178077)-[PID: 407983]–[INFO]: Building SkeletonCell.Hay.(2024-05-21 13:24:32.178738)-[PID: 407984]–[INFO]: Building SkeletonCell.Hay.(2024-05-21 13:24:32.179383)-[PID: 407985]–[INFO]: Building SkeletonCell.Hay.
#
# (2024-05-21 13:24:32.180059)-[PID: 407986]–[INFO]: Building SkeletonCell.Hay.
# (2024-05-21 13:24:32.180848)-[PID: 407987]–[INFO]: Building SkeletonCell.Hay.
# (2024-05-21 13:24:32.181533)-[PID: 407988]–[INFO]: Building SkeletonCell.Hay.
#
# (2024-05-21 13:24:32.182253)-[PID: 407989]–[INFO]: Building SkeletonCell.Hay.(2024-05-21 13:24:32.182987)-[PID: 407990]–[INFO]: Building SkeletonCell.Hay.
#
# (2024-05-21 13:24:32.183823)-[PID: 407991]–[INFO]: Building SkeletonCell.Hay.
# (2024-05-21 13:24:32.184755)-[PID: 407992]–[INFO]: Building SkeletonCell.Hay.
# (2024-05-21 13:24:32.185930)-[PID: 407993]–[INFO]: Building SkeletonCell.Hay.
# (2024-05-21 13:24:32.187038)-[PID: 407994]–[INFO]: Building SkeletonCell.Hay.
# (2024-05-21 13:24:32.187965)-[PID: 407995]–[INFO]: Building SkeletonCell.Hay.(2024-05-21 13:24:32.188770)-[PID: 407996]–[INFO]: Building SkeletonCell.Hay.
#
# (2024-05-21 13:24:32.189644)-[PID: 407997]–[INFO]: Building SkeletonCell.Hay.
# (2024-05-21 13:24:32.190492)-[PID: 407998]–[INFO]: Building SkeletonCell.Hay.
# (2024-05-21 13:24:32.191307)-[PID: 407999]–[INFO]: Building SkeletonCell.Hay.
# (2024-05-21 13:24:32.192236)-[PID: 408000]–[INFO]: Building SkeletonCell.Hay.
# (2024-05-21 13:24:32.193413)-[PID: 408001]–[INFO]: Building SkeletonCell.Hay.
# (2024-05-21 13:24:32.195843)-[PID: 408002]–[INFO]: Building SkeletonCell.Hay.(2024-05-21 13:24:32.196921)-[PID: 408005]–[INFO]: Building SkeletonCell.Hay.
#
# (2024-05-21 13:24:32.197860)-[PID: 408006]–[INFO]: Building SkeletonCell.Hay.
# (2024-05-21 13:24:32.198792)-[PID: 408007]–[INFO]: Building SkeletonCell.Hay.(2024-05-21 13:24:32.199637)-[PID: 408008]–[INFO]: Building SkeletonCell.Hay.
#
# (2024-05-21 13:24:32.200493)-[PID: 408009]–[INFO]: Building SkeletonCell.Hay.
# (2024-05-21 13:24:32
–[INFO]: Building excitatory synapses.
# (2024-05-21 13:24:32.870763)-[PID: 408074]–[INFO]: Building soma synapses.
#
# (2024-05-21 13:24:32.871848)-[PID: 408079]–[INFO]: Building excitatory synapses.
# (2024-05-21 13:24:32.872576)-[PID: 408078]–[INFO]: Building inhibitory synapses.(2024-05-21 13:24:32.872700)-[PID: 408076]–[INFO]: Building inhibitory synapses.
# (2024-05-21 13:24:32.872589)-[PID: 408080]–[INFO]: Building excitatory synapses.(2024-05-21 13:24:32.872592)-[PID: 408077]–[INFO]: Assigning excitatory spike trains.
#
# (2024-05-21 13:24:32.873397)-[PID: 408074]–[INFO]: Assigning excitatory spike trains.(2024-05-21 13:24:32.873722)-[PID: 408079]–[INFO]: Building inhibitory synapses.
#
# (2024-05-21 13:24:32.874279)-[PID: 408078]–[INFO]: Building soma synapses.
#
# (2024-05-21 13:24:32.874717)-[PID: 408076]–[INFO]: Building soma synapses.(2024-05-21 13:24:32.874663)-[PID: 408080]–[INFO]: Building inhibitory synapses.
# (2024-05-21 13:24:32.875056)-[PID: 408082]–[INFO]: Building excitatory synapses.(2024-05-21 13:24:32.875417)-[PID: 408079]–[INFO]: Building soma synapses.
# (2024-05-21 13:24:32.875365)-[PID: 408083]–[INFO]: Building excitatory synapses.
# (2024-05-21 13:24:32.875787)-[PID: 408078]–[INFO]: Assigning excitatory spike trains.
# (2024-05-21 13:24:32.876253)-[PID: 408076]–[INFO]: Assigning excitatory spike trains.(2024-05-21 13:24:32.876241)-[PID: 408086]–[INFO]: Building excitatory synapses.
# (2024-05-21 13:24:32.876523)-[PID: 408080]–[INFO]: Building soma synapses.
#
# (2024-05-21 13:24:32.876984)-[PID: 408079]–[INFO]: Assigning excitatory spike trains.
#
# (2024-05-21 13:24:32.877299)-[PID: 408082]–[INFO]: Building inhibitory synapses.(2024-05-21 13:24:32.877498)-[PID: 408083]–[INFO]: Building inhibitory synapses.
#
#
# (2024-05-21 13:24:32.877571)-[PID: 408084]–[INFO]: Building excitatory synapses.(2024-05-21 13:24:32.877719)-[PID: 408067]–[INFO]: Building excitatory synapses.(2024-05-21 13:24:32.878038)-[PID: 408086]–[INFO]: Building inhibitory synapses.(2024-05-21 13:24:32.878294)-[PID: 408080]–[INFO]: Assigning excitatory spike trains.
# (2024-05-21 13:24:32.878664)-[PID: 408083]–[INFO]: Building soma synapses.
#
#
#
#
# (2024-05-21 13:24:32.879044)-[PID: 408082]–[INFO]: Building soma synapses.(2024-05-21 13:24:32.879541)-[PID: 408084]–[INFO]: Building inhibitory synapses.(2024-05-21 13:24:32.879928)-[PID: 408083]–[INFO]: Assigning excitatory spike trains.(2024-05-21 13:24:32.879850)-[PID: 408067]–[INFO]: Building inhibitory synapses.
# (2024-05-21 13:24:32.879896)-[PID: 408086]–[INFO]: Building soma synapses.
#
#
# (2024-05-21 13:24:32.880801)-[PID: 408082]–[INFO]: Assigning excitatory spike trains.
# (2024-05-21 13:24:32.880917)-[PID: 408068]–[INFO]: Building excitatory synapses.(2024-05-21 13:24:32.881134)-[PID: 408084]–[INFO]: Building soma synapses.(2024-05-21 13:24:32.881366)-[PID: 408067]–[INFO]: Building soma synapses.
#
# (2024-05-21 13:24:32.881614)-[PID: 408086]–[INFO]: Assigning excitatory spike trains.
#
# (2024-05-21 13:24:32.882606)-[PID: 408068]–[INFO]: Building inhibitory synapses.
# (2024-05-21 13:24:32.882844)-[PID: 408084]–[INFO]: Assigning excitatory spike trains.(2024-05-21 13:24:32.882911)-[PID: 408067]–[INFO]: Assigning excitatory spike trains.
#
#
# (2024-05-21 13:24:32.884001)-[PID: 408068]–[INFO]: Building soma synapses.
# (2024-05-21 13:24:32.884420)-[PID: 408087]–[INFO]: Building excitatory synapses.(2024-05-21 13:24:32.885279)-[PID: 408068]–[INFO]: Assigning excitatory spike trains.
#
# (2024-05-21 13:24:32.886246)-[PID: 408087]–[INFO]: Building inhibitory synapses.
# (2024-05-21 13:24:32.887553)-[PID: 408087]–[INFO]: Building soma synapses.
# (2024-05-21 13:24:32.889010)-[PID: 408087]–[INFO]: Assigning excitatory spike trains.
# OMP: Error #34: System unable to allocate necessary resources for OMP thread:
# OMP: System error #11: Resource temporarily unavailable
# OMP: Hint Try decreasing the value of OMP_NUM_THREADS.
# OMP: Error #34: System unable to allocate necessary resources for OMP thread:
# OMP: System error #11: Resource temporarily unavailable
# OMP: Hint Try decreasing the value of OMP_NUM_THREADS.
# OMP: Error #34: System unable to allocate necessary resources for OMP thread:
# OMP: System error #11: Resource temporarily unavailable
# OMP: Hint Try decreasing the value of OMP_NUM_THREADS.
# OMP: Error #34: System unable to allocate necessary resources for OMP thread:
# OMP: System error #11: Resource temporarily unavailable
# OMP: Hint Try decreasing the value of OMP_NUM_THREADS.
# OMP: Error #34: System unable to allocate necessary resources for OMP thread:
# OMP: System error #11: Resource temporarily unavailable
# OMP: Hint Try decreasing the value of OMP_NUM_THREADS.
# OMP: Error #34: System unable to allocate necessary resources for OMP thread:
# OMP: System error #11: Resource temporarily unavailable
# OMP: Hint Try decreasing the value of OMP_NUM_THREADS.
# OMP: Error #34: System unable to allocate necessary resources for OMP thread:
# OMP: System error #11: Resource temporarily unavailable
# OMP: Hint Try decreasing the value of OMP_NUM_THREADS.
# OMP: Error #34: System unable to allocate necessary resources for OMP thread:
# OMP: System error #11: Resource temporarily unavailable
# OMP: Hint Try decreasing the value of OMP_NUM_THREADS.
# OMP: Error #34: System unable to allocate necessary resources for OMP thread:
# OMP: System error #11: Resource temporarily unavailable
# OMP: Hint Try decreasing the value of OMP_NUM_THREADS.
# (2024-05-21 13:25:38.770298)-[PID: 408045]–[INFO]: Assigning inhibitory spike trains.
# (2024-05-21 13:25:39.226163)-[PID: 408033]–[INFO]: Assigning inhibitory spike trains.
# (2024-05-21 13:25:44.242063)-[PID: 408085]–[INFO]: Assigning inhibitory spike trains.
# (2024-05-21 13:25:47.714920)-[PID: 407985]–[INFO]: Assigning inhibitory spike trains.
# (2024-05-21 13:25:50.661913)-[PID: 408051]–[INFO]: Assigning inhibitory spike trains.
# (2024-05-21 13:25:51.065611)-[PID: 408036]–[INFO]: Assigning inhibitory spike trains.
# (2024-05-21 13:25:52.478605)-[PID: 408035]–[INFO]: Assigning inhibitory spike trains.
# (2024-05-21 13:25:59.326090)-[PID: 407991]–[INFO]: Assigning inhibitory spike trains.
# (2024-05-21 13:25:59.338772)-[PID: 408087]–[INFO]: Assigning inhibitory spike trains.
# (2024-05-21 13:26:00.198237)-[PID: 408050]–[INFO]: Assigning inhibitory spike trains.
# (2024-05-21 13:26:00.775219)-[PID: 408018]–[INFO]: Assigning inhibitory spike trains.
# (2024-05-21 13:26:01.089846)-[PID: 408043]–[INFO]: Assigning inhibitory spike trains.
# (2024-05-21 13:26:02.073498)-[PID: 408067]–[INFO]: Assigning inhibitory spike trains.
# (2024-05-21 13:26:02.501945)-[PID: 408079]–[INFO]: Assigning inhibitory spike trains.
# (2024-05-21 13:26:02.655179)-[PID: 408038]–[INFO]: Assigning inhibitory spike trains.
# (2024-05-21 13:26:02.720716)-[PID: 408057]–[INFO]: Assigning inhibitory spike trains.
# (2024-05-21 13:26:02.730060)-[PID: 408062]–[INFO]: Assigning inhibitory spike trains.
# (2024-05-21 13:26:02.855957)-[PID: 408003]–[INFO]: Assigning inhibitory spike trains.
# (2024-05-21 13:26:02.949315)-[PID: 408044]–[INFO]: Assigning inhibitory spike trains.
# (2024-05-21 13:26:03.118513)-[PID: 408072]–[INFO]: Assigning inhibitory spike trains.
# (2024-05-21 13:26:03.202880)-[PID: 407988]–[INFO]: Assigning inhibitory spike trains.
# (2024-05-21 13:26:03.529221)-[PID: 408026]–[INFO]: Assigning inhibitory spike trains.
# (2024-05-21 13:26:03.579342)-[PID: 408082]–[INFO]: Assigning inhibitory spike trains.
# (2024-05-21 13:26:04.021499)-[PID: 407993]–[INFO]: Assigning inhibitory spike trains.
# (2024-05-21 13:26:04.044452)-[PID: 408019]–[INFO]: Assigning inhibitory spike trains.
# (2024-05-21 13:26:04.094133)-[PID: 408084]–[INFO]: Assigning inhibitory spike trains.
# (2024-05-21 13:26:04.167406)-[PID: 408074]–[INFO]: Assigning inhibitory spike trains.(2024-05-21 13:26:04.138847)-[PID: 408054]–[INFO]: Assigning inhibitory spike trains.
#
# (2024-05-21 13:26:04.194030)-[PID: 408086]–[INFO]: Assigning inhibitory spike trains.
# (2024-05-21 13:26:04.295781)-[PID: 408064]–[INFO]: Assigning inhibitory spike trains.
# (2024-05-21 13:26:04.405243)-[PID: 408081]–[INFO]: Assigning inhibitory spike trains.(2024-05-21 13:26:04.406313)-[PID: 408027]–[INFO]: Assigning inhibitory spike trains.
#
# (2024-05-21 13:26:04.430649)-[PID: 408001]–[INFO]: Assigning inhibitory spike trains.
# (2024-05-21 13:26:04.480841)-[PID: 408068]–[INFO]: Assigning inhibitory spike trains.
# (2024-05-21 13:26:04.570191)-[PID: 407990]–[INFO]: Assigning inhibitory spike trains.
# (2024-05-21 13:26:04.480606)-[PID: 408009]–[INFO]: Assigning inhibitory spike trains.
# (2024-05-21 13:26:05.247459)-[PID: 408040]–[INFO]: Assigning inhibitory spike trains.
# (2024-05-21 13:26:05.216739)-[PID: 408080]–[INFO]: Assigning inhibitory spike trains.
# (2024-05-21 13:26:05.589939)-[PID: 408071]–[INFO]: Assigning inhibitory spike trains.
# (2024-05-21 13:26:05.679631)-[PID: 408052]–[INFO]: Assigning inhibitory spike trains.
# (2024-05-21 13:26:05.968316)-[PID: 408061]–[INFO]: Assigning inhibitory spike trains.
# (2024-05-21 13:26:06.202702)-[PID: 408048]–[INFO]: Assigning inhibitory spike trains.
# (2024-05-21 13:26:06.290809)-[PID: 408075]–[INFO]: Assigning inhibitory spike trains.
# (2024-05-21 13:26:06.418445)-[PID: 408032]–[INFO]: Assigning inhibitory spike trains.(2024-05-21 13:26:06.428118)-[PID: 408022]–[INFO]: Assigning inhibitory spike trains.
#
# ...
# (2024-05-21 13:28:02.896942)-[PID: 408012]–[INFO]: Saving data at step: 20000
# (2024-05-21 13:28:02.910573)-[PID: 408012]–[INFO]: Finished writing data
# (2024-05-21 13:28:02.912122)-[PID: 408012]–[INFO]: Finished clearing recorders
# (2024-05-21 13:28:02.914804)-[PID: 408012]–[INFO]: Finish simulation in 2.679 seconds
# (2024-05-21 13:28:03.228622)-[PID: 408059]–[INFO]: Saving data at step: 10000
# (2024-05-21 13
–[INFO]: Saving data at step: 20000
# (2024-05-21 13:28:07.451017)-[PID: 408011]–[INFO]: Finish simulation in 8.102 seconds
# (2024-05-21 13:28:07.462490)-[PID: 408014]–[INFO]: Saving data at step: 20000
# (2024-05-21 13:28:07.472833)-[PID: 407986]–[INFO]: Saving data at step: 20000
# (2024-05-21 13:28:07.481141)-[PID: 408001]–[INFO]: Finished writing data
# (2024-05-21 13:28:07.482903)-[PID: 408001]–[INFO]: Finished clearing recorders
# (2024-05-21 13:28:07.488878)-[PID: 408001]–[INFO]: Finish simulation in 8.236 seconds
# (2024-05-21 13:28:07.493130)-[PID: 408014]–[INFO]: Finished writing data
# (2024-05-21 13:28:07.494766)-[PID: 408014]–[INFO]: Finished clearing recorders
# (2024-05-21 13:28:07.499878)-[PID: 408014]–[INFO]: Finish simulation in 6.487 seconds
# (2024-05-21 13:28:07.511190)-[PID: 407986]–[INFO]: Finished writing data
# (2024-05-21 13:28:07.512960)-[PID: 407986]–[INFO]: Finished clearing recorders
# (2024-05-21 13:28:07.518975)-[PID: 407986]–[INFO]: Finish simulation in 8.245 seconds
# (2024-05-21 13:28:07.668814)-[PID: 408041]–[INFO]: Saving data at step: 20000
# (2024-05-21 13:28:07.696941)-[PID: 408041]–[INFO]: Finished writing data
# (2024-05-21 13:28:07.698768)-[PID: 408041]–[INFO]: Finished clearing recorders
# (2024-05-21 13:28:07.704283)-[PID: 408041]–[INFO]: Finish simulation in 7.946 seconds
# (2024-05-21 13:28:07.749375)-[PID: 407996]–[INFO]: Saving data at step: 20000
# (2024-05-21 13:28:07.777384)-[PID: 407996]–[INFO]: Finished writing data
# (2024-05-21 13:28:07.779483)-[PID: 407996]–[INFO]: Finished clearing recorders
# (2024-05-21 13:28:07.785279)-[PID: 407996]–[INFO]: Finish simulation in 8.111 seconds
# (2024-05-21 13:28:07.824100)-[PID: 407994]–[INFO]: Saving data at step: 20000(2024-05-21 13:28:07.824844)-[PID: 408031]–[INFO]: Saving data at step: 20000
#
# (2024-05-21 13:28:07.847079)-[PID: 407994]–[INFO]: Finished writing data
# (2024-05-21 13:28:07.848674)-[PID: 407994]–[INFO]: Finished clearing recorders
# (2024-05-21 13:28:07.849028)-[PID: 408031]–[INFO]: Finished writing data
# (2024-05-21 13:28:07.850716)-[PID: 408031]–[INFO]: Finished clearing recorders
# (2024-05-21 13:28:07.853215)-[PID: 407994]–[INFO]: Finish simulation in 6.399 seconds
# (2024-05-21 13:28:07.856105)-[PID: 408031]–[INFO]: Finish simulation in 7.893 seconds
# (2024-05-21 13:28:08.114659)-[PID: 408066]–[INFO]: Saving data at step: 20000
# (2024-05-21 13:28:08.150008)-[PID: 408066]–[INFO]: Finished writing data
# (2024-05-21 13:28:08.151812)-[PID: 408066]–[INFO]: Finished clearing recorders
# (2024-05-21 13:28:08.157357)-[PID: 408066]–[INFO]: Finish simulation in 8.092 seconds
# (2024-05-21 13:28:08.685527)-[PID: 408056]–[INFO]: Saving data at step: 20000
# (2024-05-21 13:28:08.717026)-[PID: 408056]–[INFO]: Finished writing data
# (2024-05-21 13:28:08.718866)-[PID: 408056]–[INFO]: Finished clearing recorders
# (2024-05-21 13:28:08.724574)-[PID: 408056]–[INFO]: Finish simulation in 7.803 seconds
# (2024-05-21 13:28:08.882068)-[PID: 408076]–[INFO]: Saving data at step: 20000
# (2024-05-21 13:28:08.917026)-[PID: 408076]–[INFO]: Finished writing data
# (2024-05-21 13:28:08.918881)-[PID: 408076]–[INFO]: Finished clearing recorders
# (2024-05-21 13:28:08.924399)-[PID: 408076]–[INFO]: Finish simulation in 7.971 seconds
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# plot FI with synapses and no mapping
import os
import numpy as np

# Define the template for common attributes
common_attributes = {
    'h_tstop': 2000,
    'all_synapses_off': False,
    'CI_on': True,
    'h_i_duration': 1950,
    'h_i_delay': 50,
    'synapse_mapping': False
}

# Define the varying attributes for each sim_name, without including 'sim_name' key
varying_attributes = [
    {'base_sim_name': 'Complex', 'reduce_cell_selective': False},
    {'base_sim_name': 'Basals', 'reduce_basals': True},
    {'base_sim_name': 'Tufts', 'reduce_tufts': True},
    {'base_sim_name': 'Obliques', 'reduce_obliques': True},
    {'base_sim_name': 'All', 'reduce_obliques': True, 'reduce_tufts': True, 'reduce_basals': True}
]

# Generate the list of HayParameters with updated sim_names
all_parameters = [
    HayParameters(
        **common_attributes,
        h_i_amplitude=round(amp, 1),
        sim_name=f"{attributes['base_sim_name']}_amp_{round(amp, 1)}",
        **{k: v for k, v in attributes.items() if k != 'base_sim_name'}
    )
    for amp in np.arange(-2, 2.1, 0.2)
    for attributes in varying_attributes
]

# Initialize simulation
sim = Simulation(SkeletonCell.Hay, title='FI_SynapsesNoMapping')

# Submit jobs to simulation
for parameters in all_parameters:
    sim.submit_job(parameters)

# Remove directory if it exists
try:
    os.system("rm -r x86_64/")
except:
    pass

# Run the simulation
sim.run()

# Create directory for saving results
output_dir = f"../notebooks/{sim.title}"
os.makedirs(output_dir, exist_ok=True)

# Get all parameter paths
all_parameters_paths = [parameters.path for parameters in all_parameters]

# Plot results and save to the directory
plot_command = f"python3 plot_fi.py -d {sim.path} -s {output_dir}"
os.system(plot_command)

# %%
# plot FI with synapses and no mapping; 1000 synapses
import os
import numpy as np

# Define the template for common attributes
common_attributes = {
    'h_tstop': 2000,
    'all_synapses_off': False,
    'CI_on': True,
    'h_i_duration': 1950,
    'h_i_delay': 50,
    'synapse_mapping': False,
    'exc_use_density': False,
    'inh_use_density': False
}

# Define the varying attributes for each sim_name, without including 'sim_name' key
varying_attributes = [
    {'base_sim_name': 'Complex', 'reduce_cell_selective': False},
    {'base_sim_name': 'Basals', 'reduce_basals': True},
    {'base_sim_name': 'Tufts', 'reduce_tufts': True},
    {'base_sim_name': 'Obliques', 'reduce_obliques': True},
    {'base_sim_name': 'All', 'reduce_obliques': True, 'reduce_tufts': True, 'reduce_basals': True}
]

# Generate the list of HayParameters with updated sim_names
all_parameters = [
    HayParameters(
        **common_attributes,
        h_i_amplitude=round(amp, 1),
        sim_name=f"{attributes['base_sim_name']}_amp_{round(amp, 1)}",
        **{k: v for k, v in attributes.items() if k != 'base_sim_name'}
    )
    for amp in np.arange(-2, 2.1, 0.2)
    for attributes in varying_attributes
]

# Initialize simulation
sim = Simulation(SkeletonCell.Hay, title='FI_SynapsesNoMapping1000Syn')

# Submit jobs to simulation
for parameters in all_parameters:
    sim.submit_job(parameters)

# Remove directory if it exists
try:
    os.system("rm -r x86_64/")
except:
    pass

# Run the simulation
sim.run()

# Create directory for saving results
output_dir = f"../notebooks/{sim.title}"
os.makedirs(output_dir, exist_ok=True)

# Get all parameter paths
all_parameters_paths = [parameters.path for parameters in all_parameters]

# Plot results and save to the directory
plot_command = f"python3 plot_fi.py -d {sim.path} -s {output_dir}"
os.system(plot_command)

# %%
# plot FI with synapses and no mapping; 1000 synapses
import os
import numpy as np

# Define the template for common attributes
common_attributes = {
    'h_tstop': 10000
}

# Define the varying attributes for each sim_name, without including 'sim_name' key
varying_attributes = [
    {'base_sim_name': 'Complex', 'reduce_cell_selective': False},
    {'base_sim_name': 'Basals', 'reduce_basals': True},
    {'base_sim_name': 'Tufts', 'reduce_tufts': True},
    {'base_sim_name': 'Obliques', 'reduce_obliques': True},
    {'base_sim_name': 'All', 'reduce_obliques': True, 'reduce_tufts': True, 'reduce_basals': True}
]

# Generate the list of HayParameters with updated sim_names
all_parameters = [
    HayParameters(
        **common_attributes,
        h_i_amplitude=round(amp, 1),
        sim_name=f"{attributes['base_sim_name']}",
        **{k: v for k, v in attributes.items() if k != 'base_sim_name'}
    )
    for amp in np.arange(-2, 2.1, 0.2)
    for attributes in varying_attributes
]

# Initialize simulation
sim = Simulation(SkeletonCell.Hay, title='STA')

# Submit jobs to simulation
for parameters in all_parameters:
    sim.submit_job(parameters)

# Remove directory if it exists
try:
    os.system("rm -r x86_64/")
except:
    pass

# Run the simulation
sim.run()

# Create directory for saving results
output_dir = f"../notebooks/{sim.title}"
os.makedirs(output_dir, exist_ok=True)

# Get all parameter paths
all_parameters_paths = [parameters.path for parameters in all_parameters]

# Plot results and save to the directory
plot_command = f"python3 plot_sta.py -d {sim.path} -s {output_dir}"
os.system(plot_command)

# %%
# %matplotlib widget

import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from ipywidgets import interactive, fixed, FloatSlider

# Setup a global reference for figure and axes
fig, ax = None, None

def plot_segments(seg_data, elevation=0, azimuth=-100, radius_scale=1.0, deleted_indices=[]):
    global fig, ax
    if fig is None or ax is None:
        plt.close('all')  # Close any existing plots
        fig = plt.figure()
        ax = fig.add_subplot(111, projection='3d')
    else:
        ax.cla()  # Clear the existing axes

    for i, seg in enumerate(seg_data):
        x_points = [seg.coords['p0_0'].iloc[0], seg.coords['pc_0'].iloc[0], seg.coords['p1_0'].iloc[0]]
        y_points = [seg.coords['p0_1'].iloc[0], seg.coords['pc_1'].iloc[0], seg.coords['p1_1'].iloc[0]]
        z_points = [seg.coords['p0_2'].iloc[0], seg.coords['pc_2'].iloc[0], seg.coords['p1_2'].iloc[0]]

        radius = seg.coords['r'].iloc[0] * radius_scale
        color = 'red' if i in deleted_indices else 'black'
        radius = radius*0.1 if i in deleted_indices else radius # can adjust multiplier to increase red radius
        ax.plot(x_points, z_points, y_points, linewidth=radius, color=color)

    ax.view_init(elev=elevation, azim=azimuth)
    ax.set_xlabel('X')
    ax.set_ylabel('Z')
    ax.set_zlabel('Y')

# %%
from Modules.morph_reduction_utils import get_reduced_cell

# %%
os.mkdir(sim.path)
parameters.path = os.path.join(sim.path, parameters.sim_name)

# %%
os.mkdir(parameters.path)

# %%
logger = Logger(None)
cell_builder = CellBuilder(sim.cell_type, parameters, logger)

# %%
complex_cell, _ = cell_builder.build_cell()
reduced_cell_tufts, original_seg_data, all_deleted_seg_indices = get_reduced_cell(cell_builder, reduce_tufts = True, reduce_obliques = False)
reduced_cell_obliques, original_seg_data, all_deleted_seg_indices = get_reduced_cell(cell_builder, reduce_tufts = False, reduce_obliques = True)
reduced_cell_basals, original_seg_data, all_deleted_seg_indices = get_reduced_cell(cell_builder, reduce_basals = True)
reduced_cell_tufts_basals, original_seg_data, all_deleted_seg_indices = get_reduced_cell(cell_builder, reduce_tufts = True, reduce_basals = True, reduce_obliques = False)
reduced_cell_tufts_basals_obliques, original_seg_data, all_deleted_seg_indices = get_reduced_cell(cell_builder, reduce_tufts = True, reduce_basals = True, reduce_obliques = True)
reduced_cell_tufts_obliques, original_seg_data, all_deleted_seg_indices = get_reduced_cell(cell_builder, reduce_tufts = True, reduce_basals = False, reduce_obliques = True)
reduced_cell_basals_obliques, original_seg_data, all_deleted_seg_indices = get_reduced_cell(cell_builder, reduce_tufts = False, reduce_basals = True, reduce_obliques = True)

cells = {
    'Complex':complex_cell,
    'Reduced Tufts':reduced_cell_tufts,
    'Reduced Basals':reduced_cell_basals,
    'Reduced Obliques':reduced_cell_obliques,
    'Reduced Tufts and Basals':reduced_cell_tufts_basals,
    'Reduced Tufts and Obliques':reduced_cell_tufts_obliques,
    'Reduced Basals and Obliques':reduced_cell_basals_obliques,
    'Reduced Tufts, Basals, Obliques': reduced_cell_tufts_basals_obliques
}

# %%
# define custom synpase distribution ( in this case 700 exc 300 inh)
from spike_generator import PoissonTrainGenerator
from presynaptic import PCBuilder
from functools import partial
import scipy.stats as st

def build_synapses(cell, random_state):
    # craete synapse objects
    #self.logger.log("Building excitatory synapses.")
    build_excitatory_synapses(cell = cell)

    #self.logger.log("Building inhibitory synapses.")
    build_inhibitory_synapses(cell = cell)

    #self.logger.log("Building soma synapses.")
    build_soma_synapses(cell = cell)

    # Assign spike trains
    #self.logger.log("Assigning excitatory spike trains.")
    assign_exitatory_spike_trains(cell = cell, random_state = random_state)

    #self.logger.log("Assigning inhibitory spike trains.")
    assign_inhibitory_spike_trains(cell = cell, random_state = random_state)

    #self.logger.log("Assigning soma spike trains.")
    assign_soma_spike_trains(cell = cell, random_state = random_state)

def binned_log_norm_dist(gmax_mean, gmax_std, gmax_scalar, size, clip):
	val = np.random.lognormal(gmax_mean, gmax_std, size)
	s = gmax_scalar * float(np.clip(val, clip[0], clip[1]))

	# Bin
	num_bins = 10
	bin_size = (clip[1] - clip[0]) / num_bins
	bins = np.arange(0, clip[1], bin_size)
	ind = np.digitize(s, bins)

	if ind == num_bins:
		return bins[-1]
	else:
		return bins[ind]

def assign_soma_spike_trains(cell, random_state) -> None:

    PCBuilder.assign_presynaptic_cells(
        cell = cell,
        n_func_gr = 1,
        n_pc_per_fg = 1,
        synapse_names = ["soma"]
    )

    # Proximal inh mean_fr distribution
    mean_fr, std_fr = parameters.inh_prox_mean_fr, parameters.inh_prox_std_fr
    a, b = (0 - mean_fr) / std_fr, (100 - mean_fr) / std_fr
    proximal_inh_dist = partial(st.truncnorm.rvs, a = a, b = b, loc = mean_fr, scale = std_fr)

    for i, synapse in enumerate(cell.synapses):
        if synapse.name == "soma":
            mean_fr = proximal_inh_dist(size = 1)
            firing_rates = PoissonTrainGenerator.generate_lambdas_from_pink_noise(
                num = parameters.h_tstop,
                random_state = random_state,
                lambda_mean = mean_fr)
            spike_train = PoissonTrainGenerator.generate_spike_train(
                lambdas = firing_rates, 
                random_state = random_state)

            cell.synapses[i].set_spike_train_for_pc(mean_fr = mean_fr, spike_train = spike_train.spike_times)


def assign_inhibitory_spike_trains(cell, random_state) -> None:

    PCBuilder.assign_presynaptic_cells(
        cell = cell,
        n_func_gr = parameters.inh_distributed_n_FuncGroups,
        n_pc_per_fg = parameters.inh_distributed_n_PreCells_per_FuncGroup,
        synapse_names = ["inh"]
    )

    # Proximal inh mean_fr distribution
    mean_fr, std_fr = parameters.inh_prox_mean_fr, parameters.inh_prox_std_fr
    a, b = (0 - mean_fr) / std_fr, (100 - mean_fr) / std_fr
    proximal_inh_dist = partial(st.truncnorm.rvs, a = a, b = b, loc = mean_fr, scale = std_fr)

    # Distal inh mean_fr distribution
    mean_fr, std_fr = parameters.inh_distal_mean_fr, parameters.inh_distal_std_fr
    a, b = (0 - mean_fr) / std_fr, (100 - mean_fr) / std_fr
    distal_inh_dist = partial(st.truncnorm.rvs, a = a, b = b, loc = mean_fr, scale = std_fr)

    soma_coords = cell.get_segments(["soma"])[1][0].coords[["pc_0", "pc_1", "pc_2"]].to_numpy()

    for i, synapse in enumerate(cell.synapses):
        if synapse.name == "inh":
            if np.linalg.norm(soma_coords - synapse.pc.cluster_center) < 100:
                mean_fr = proximal_inh_dist(size = 1)
            else:
                mean_fr = distal_inh_dist(size = 1)

            firing_rates = PoissonTrainGenerator.generate_lambdas_from_pink_noise(
                num = parameters.h_tstop,
                random_state = random_state,
                lambda_mean = mean_fr)
            spike_train = PoissonTrainGenerator.generate_spike_train(
                lambdas = firing_rates, 
                random_state = random_state)
            
            cell.synapses[i].set_spike_train_for_pc(mean_fr = mean_fr, spike_train = spike_train.spike_times)


def assign_exitatory_spike_trains(cell, random_state) -> None:

    PCBuilder.assign_presynaptic_cells(
        cell = cell,
        n_func_gr = parameters.exc_n_FuncGroups,
        n_pc_per_fg = parameters.exc_n_PreCells_per_FuncGroup,
        synapse_names = ["exc"]
    )

    # Distribution of mean firing rates
    # mean_fr_dist = partial(gamma_dist, mean = self.parameters.exc_mean_fr, size = 1)
    mean_fr, std_fr = parameters.exc_mean_fr, parameters.exc_std_fr
    a, b = (0 - mean_fr) / std_fr, (100 - mean_fr) / std_fr
    mean_fr_dist = partial(st.truncnorm.rvs, a = a, b = b, loc = mean_fr, scale = std_fr)

    for i, synapse in enumerate(cell.synapses):
        if synapse.name == "exc":
            mean_fr = mean_fr_dist(size = 1)
            firing_rates = PoissonTrainGenerator.generate_lambdas_from_pink_noise(
                num = parameters.h_tstop,
                random_state = random_state,
                lambda_mean = mean_fr)
            spike_train = PoissonTrainGenerator.generate_spike_train(
                lambdas = firing_rates, 
                random_state = random_state)
            cell.synapses[i].set_spike_train_for_pc(mean_fr = mean_fr, spike_train = spike_train.spike_times)

            
def build_soma_synapses(cell) -> None:
    
    if (parameters.CI_on) or (not parameters.add_soma_inh_synapses):
        return None
    
    # inh_soma_P_dist = partial(
    # 	P_release_dist, 
    # 	P_mean = self.parameters.inh_soma_P_release_mean, 
    # 	P_std = self.parameters.inh_soma_P_release_std, 
    # 	size = 1)
    
    segments, seg_data = cell.get_segments(["soma"])
    probs = [data.membrane_surface_area for data in seg_data]
    
    cell.add_synapses_over_segments(
        segments = segments,
        nsyn = 100,
        syn_mod = parameters.inh_syn_mod,
        syn_params = parameters.inh_syn_params,
        gmax = parameters.soma_gmax_dist,
        name = "soma",
        density = False,
        seg_probs = probs,
        release_p = None)
        
def build_inhibitory_synapses(cell) -> None:
    
    if parameters.CI_on:
        return None
    
    # Inhibitory release probability distributions
    # inh_apic_P_dist = partial(
    # 	P_release_dist, 
    # 	P_mean = self.parameters.inh_apic_P_release_mean, 
    # 	P_std = self.parameters.inh_apic_P_release_std, 
    # 	size = 1)
    # inh_basal_P_dist = partial(
    # 	P_release_dist, 
    # 	P_mean = self.parameters.inh_basal_P_release_mean, 
    # 	P_std = self.parameters.inh_basal_P_release_std, 
    # 	size = 1)
    
    # inh_P_dist = {}
    # inh_P_dist["apic"] = inh_apic_P_dist
    # inh_P_dist["dend"] = inh_basal_P_dist
    
    segments, seg_data = cell.get_segments(["apic", "dend"])
    probs = [data.membrane_surface_area for data in seg_data]

    cell.add_synapses_over_segments(
        segments = segments,
        nsyn = 200,
        syn_mod = parameters.inh_syn_mod,
        syn_params = parameters.inh_syn_params,
        gmax = parameters.inh_gmax_dist,
        name = "inh",
        density = False,
        seg_probs = probs,
        release_p = None)
        
def build_excitatory_synapses(cell) -> None:
    
    if parameters.CI_on:
        return None

    # Excitatory gmax distribution
    gmax_exc_dist = partial(
        binned_log_norm_dist,#log_norm_dist, 
        parameters.exc_gmax_mean_0, 
        parameters.exc_gmax_std_0, 
        parameters.exc_scalar, 
        size = 1, 
        clip = parameters.exc_gmax_clip)
    
    # exc release probability distribution everywhere
    # exc_P_dist = partial(
    # 	P_release_dist, 
    # 	P_mean = self.parameters.exc_P_release_mean, 
    # 	P_std = self.parameters.exc_P_release_std, 
    # 	size = 1)

    segments, seg_data = cell.get_segments(["apic", "dend"])
    if parameters.use_SA_exc:
        probs = [data.membrane_surface_area for data in seg_data]
    else:
        raise NotImplementedError

    cell.add_synapses_over_segments(
        segments = segments,
        nsyn = 700,
        syn_mod = parameters.exc_syn_mod,
        syn_params = parameters.exc_syn_params,
        gmax = gmax_exc_dist,
        name = "exc",
        density = False,
        seg_probs = probs,
        release_p = None)

# %%
# build synapses (2 cases)

for cell_name, cell in cells.items():
    random_state = np.random.RandomState(parameters.numpy_random_state)
    # cell_builder.build_synapses(cell, random_state) # with synaptic densities as defined by constants.py & original script/code
    build_synapses(cell, random_state) # with 1000 synapses as defined by the functions in this notebook.

# %% [markdown]
# Show Reduced Cell

# %%
parameters.record_ecp = True

# %%
import Modules.analysis as analysis

# %%
# !python3 plot_lfp.py -d SkeletonCell.Hay-07-05-2024-17-20-41/test

# %% [markdown]
# Some Notes:
# Compare detailed and reduced
# Try allen database cell
# 1. We adapted neuron_reduce for more user-control.
# 2. Currently not Mapping synapses, but it will be easy to add.
# 3. We could convert single-cylinders into an equivalent set of nbranches.

# %% [markdown]
# COMPARISONS

# %%
for cell_name, cell in cells.items():
    sim.set_all_recorders(cell, parameters)

# %%
try:os.mkdir(parameters.path)
except:print('pass')

# %%
import shutil
import os
import pickle
import numpy as np
import matplotlib.pyplot as plt
import csv
from scipy.stats import pearsonr

# Adjust the parameters and initialize the cell structure here
root_path = parameters.path
FI_paths = []
parameters.h_tstop = 5000
parameters.h_i_duration = 1950
parameters.h_i_delay = 50
# amps = np.arange(-2, 2.1, 0.2)

# Prepare subplots: one for the somatic injection, another for the nexus injection
fig, axes = plt.subplots(1, 1, figsize=(12, 6))

# Create a CSV file to store the results
csv_file_path = "FI_Curve_Data.csv"
with open(csv_file_path, mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(["Cell Name", "Firing Rate (Hz)"])

    # Dictionary to store data for each cell
    cell_data = {}

    for ax in [axes]:
        for cell_name, cell in cells.items():
            firing_rates = []

            parameters.path = root_path + f"/{cell_name}_synapses"
            # os.mkdir(parameters.path)
            # with open(os.path.join(parameters.path, "parameters.pickle"), "wb") as file:
            #     pickle.dump(parameters, file)
            FI_paths.append(parameters.path)

            # Perform simulation
            print(f"simulating {cell_name}")
            sim.simulate(cell, parameters)

            # Read the voltage and spike data
            v = analysis.DataReader.read_data(parameters.path, "v", parameters=parameters)
            soma_spikes = analysis.DataReader.read_data(parameters.path, "soma_spikes", parameters=parameters)

            # Calculate the firing rate
            firing_rate = len(soma_spikes[0]) / (parameters.h_tstop / 1000)
            firing_rates.append(firing_rate)

            # Write the results to the CSV file
            writer.writerow([cell_name, firing_rate])

            # Store the data for later analysis
            cell_data[cell_name] = v[0]

            label = cell_name
            ax.plot(np.arange(0, len(v[0])), v[0], label=parameters.path)

        ax.set_title(cell_name)
        ax.set_xlabel('Time')
        ax.set_ylabel('Somatic Vm')
        # ax.set_xlim(0,2)
        ax.legend()

# Display the plots
plt.tight_layout()

# Save the figure to the current directory
plt.savefig("Synapses_Vm_no_mapping.png")  # You can specify other formats like 'pdf' by changing the file extension

plt.show()

# Clean up temporary directories
for FI_path in FI_paths:
    shutil.rmtree(FI_path)

# Compute correlations with the "Complex Cell" data
complex_cell_data = cell_data.get("Complex")
correlations = {}
if complex_cell_data is not None:
    for cell_name, data in cell_data.items():
        if cell_name != "Complex":
            correlation, _ = pearsonr(complex_cell_data, data)
            correlations[cell_name] = correlation

# Print correlations
for cell_name, correlation in correlations.items():
    print(f"Correlation between Complex Cell and {cell_name}: {correlation}")

# Optionally, store the data and correlations in a file
with open("Cell_Data_and_Correlations.pkl", "wb") as file:
    pickle.dump({"cell_data": cell_data, "correlations": correlations}, file)
    
parameters.path = root_path

# %%
cell_data.get('Complex')

# %%
# Print correlations
for cell_name, correlation in correlations.items():
    print(f"Correlation between Complex Cell and {cell_name}: {correlation}")

# %% [markdown]
# Now with current injection.

# %%
root_path

# %%
from Modules.notebook_utils import plot_FI

# %%
# F/I with synapses

for cell_name, cell in cells.items():
    cell.set_injection(amp = 0, dur = 1950, delay = 50, target='soma')
plot_FI(cells, parameters=parameters, savename = "1000SynapsesFI.png")
