# %%
# %cd ../scripts/
# Out:
# /home/drfrbc/Neural-Modeling/scripts

# %%
sim_directory = "/home/drfrbc/Neural-Modeling/scripts/2025-03-14-08-52-all3_stas_multiple_seeds"

# %%
# from count_spikes_across_seeds import count_events
from count_spikes_across_seeds import aggregate_simulation_data

# %%
# Generate .csv's for dendritic events
# !python find_events_ben.py -f {sim_directory}
# Out:
# simulations_directory: /home/drfrbc/Neural-Modeling/scripts/2025-03-14-08-52-all3_stas_multiple_seeds
# sim_directory: sta_ReduceBranches_Np5000
# sim_directory: sta_ReduceTrees_Np123456789
# sim_directory: sta_Complex_Np123456789
# sim_directory: sta_ReduceTrees_Np4444444
# sim_directory: sta_ReduceTrees_Np5000
# sim_directory: sta_ReduceBranches_Np4444444
# sim_directory: sta_Complex_Np4444444
# sim_directory: sta_Complex_Np5000
# sim_directory: sta_ReduceBranches_Np123456789

# %%
import sys
import os
sys.path.append(os.path.abspath(".."))
sys.path.append(os.path.abspath("../Modules"))
from Modules import synapse
# Out:
# Warning: no DISPLAY environment variable.
# --No graphics will be displayed.

# %%
spike_table = aggregate_simulation_data(sim_directory)
# Out:
# Retry 1/1000 failed: Trace length is 14 not 20, retrying...
# Retry 2/1000 failed: Trace length is 14 not 20, retrying...
# Retry 3/1000 failed: Trace length is 14 not 20, retrying...
# Retry 4/1000 failed: Trace length is 14 not 20, retrying...
# Retry 5/1000 failed: Trace length is 14 not 20, retrying...
# Retry 6/1000 failed: Trace length is 14 not 20, retrying...
# Retry 7/1000 failed: Trace length is 14 not 20, retrying...
# Retry 8/1000 failed: Trace length is 14 not 20, retrying...
# Retry 9/1000 failed: Trace length is 14 not 20, retrying...
# Retry 10/1000 failed: Trace length is 14 not 20, retrying...
# Retry 11/1000 failed: Trace length is 14 not 20, retrying...
# Retry 12/1000 failed: Trace length is 14 not 20, retrying...
# Retry 13/1000 failed: Trace length is 14 not 20, retrying...
# Retry 14/1000 failed: Trace length is 14 not 20, retrying...
# Retry 15/1000 failed: Trace length is 14 not 20, retrying...
# Retry 16/1000 failed: Trace length is 14 not 20, retrying...
# Retry 17/1000 failed: Trace length is 14 not 20, retrying...
# Retry 18/1000 failed: Trace length is 14 not 20, retrying...
# Retry 19/1000 failed: Trace length is 14 not 20, retrying...
# Retry 20/1000 failed: Trace length is 14 not 20, retrying...
# Retry 21/1000 failed: Trace length is 14 not 20, retrying...
# Retry 22/1000 failed: Trace length is 14 not 20, retrying...
# Retry 23/1000 failed: Trace length is 14 not 20, retrying...
# Retry 24/1000 failed: Trace length is 14 not 20, retrying...
# Retry 25/1000 failed: Trace length is 14 not 20, retrying...
# Retry 26/1000 failed: Trace length is 14 not 20, retrying...
# Retry 27/1000 failed: Trace length is 14 not 20, retrying...
# Retry 28/1000 failed: Trace length is 14 not 20, retrying...
# Retry 29/1000 failed: Trace length is 14 not 20, retrying...
# Retry 30/1000 failed: Trace length is 14 not 20, retrying...
# Retry 31/1000 failed: Trace length is 14 not 20, retrying...
# Retry 32/1000 failed: Trace length is 14 not 20, retrying...
# Retry 33/1000 failed: Trace length is 14 not 20, retrying...
# Retry 34/1000 failed: Trace length is 14 not 20, retrying...
# Retry 35/1000 failed: Trace length is 14 not 20, retrying...
# Retry 36/1000 failed: Trace length is 14 not 20, retrying...
# Retry 37/1000 failed: Trace length is 14 not 20, retrying...
# Retry 38/1000 failed: Trace length is 14 not 20, retrying...
# Retry 39/1000 failed: Trace length is 14 not 20, retrying...
# Retry 40/1000 failed: Trace length is 14 not 20, retrying...
# Retry 41/1000 failed: Trace length is 14 not 20, retrying...
# Retry 42/1000 failed: Trace length is 14 not 20, retrying...
# Retry 43/1000 failed: Trace length is 14 not 20, retrying...
# Retry 44/1000 failed: Trace length is 14 not 20, retrying...
# Retry 45/1000 failed: Trace length is 14 not 20, retrying...
# /home/drfrbc/Neural-Modeling/scripts/count_spikes_across_seeds.py:119: DtypeWarning: Columns (33) have mixed types. Specify dtype option on import or set low_memory=False.
#   na_df = pd.read_csv(os.path.join(sim_path, 'na.csv'))
# /home/drfrbc/Neural-Modeling/scripts/count_spikes_across_seeds.py:174: DtypeWarning: Columns (33) have mixed types. Specify dtype option on import or set low_memory=False.
#   nmda_df = pd.read_csv(os.path.join(sim_path, 'nmda.csv'))
# /home/drfrbc/Neural-Modeling/scripts/count_spikes_across_seeds.py:119: DtypeWarning: Columns (33) have mixed types. Specify dtype option on import or set low_memory=False.
#   na_df = pd.read_csv(os.path.join(sim_path, 'na.csv'))
# /home/drfrbc/Neural-Modeling/scripts/count_spikes_across_seeds.py:174: DtypeWarning: Columns (33) have mixed types. Specify dtype option on import or set low_memory=False.
#   nmda_df = pd.read_csv(os.path.join(sim_path, 'nmda.csv'))
# /home/drfrbc/Neural-Modeling/scripts/count_spikes_across_seeds.py:119: DtypeWarning: Columns (33) have mixed types. Specify dtype option on import or set low_memory=False.
#   na_df = pd.read_csv(os.path.join(sim_path, 'na.csv'))
# /home/drfrbc/Neural-Modeling/scripts/count_spikes_across_seeds.py:174: DtypeWarning: Columns (33) have mixed types. Specify dtype option on import or set low_memory=False.
#   nmda_df = pd.read_csv(os.path.join(sim_path, 'nmda.csv'))

# %%
spike_table
# Out:
#    Segment_Type  Total_NMDA_Spikes_per_micron  Total_NA_Spikes_per_micron  \
# 0          apic                      0.010056                    0.010502
# 1          dend                      0.063373                    0.056722
# 2          apic                      0.000000                    0.000166
# 3          dend                      0.024422                    0.046691
# 4          apic                      0.248706                    0.462820
# 5          dend                      0.381319                    0.670187
# 6          apic                      0.000124                    0.001283
# 7          dend                      0.024972                    0.038398
# 8          apic                      0.000000                    0.000248
# 9          dend                      0.048341                    0.013929
# 10         apic                      0.003148                    0.015201
# 11         dend                      0.037451                    0.097417
# 12         apic                      0.207945                    0.518606
# 13         dend                      0.341697                    0.710374
# 14         apic                      0.272185                    0.417745
# 15         dend                      0.494634                    0.390787
# 16         apic                      0.007001                    0.018279
# 17         dend                      0.038024                    0.094937
#
#     Total_CA_Spikes_per_micron            simulation_directory
# 0                     0.000141       sta_ReduceBranches_Np5000
# 1                     0.000000       sta_ReduceBranches_Np5000
# 2                     0.000000     sta_ReduceTrees_Np123456789
# 3                     0.000000     sta_ReduceTrees_Np123456789
# 4                     0.010644         sta_Complex_Np123456789
# 5                     0.000000         sta_Complex_Np123456789
# 6                     0.000000       sta_ReduceTrees_Np4444444
# 7                     0.000000       sta_ReduceTrees_Np4444444
# 8                     0.000000          sta_ReduceTrees_Np5000
# 9                     0.000000          sta_ReduceTrees_Np5000
# 10                    0.000000    sta_ReduceBranches_Np4444444
# 11                    0.000000    sta_ReduceBranches_Np4444444
# 12                    0.006075           sta_Complex_Np4444444
# 13                    0.000000           sta_Complex_Np4444444
# 14                    0.005161              sta_Complex_Np5000
# 15                    0.000000              sta_Complex_Np5000
# 16                    0.000141  sta_ReduceBranches_Np123456789
# 17                    0.000000  sta_ReduceBranches_Np123456789

# %%
from Modules import analysis
import os

# Initialize lists to store results
soma_firing_rates = []
morphologies = []
seeds = []

# Compute the soma firing rate for each simulation directory
for sim_dir in spike_table.simulation_directory:
    sim_path = os.path.join(sim_directory, sim_dir)
    
    # Read soma spikes data
    spks = analysis.DataReader.read_data(sim_path, "soma_spikes")
    
    # Load simulation parameters to get h_tstop, morphology, and seed
    params = analysis.DataReader.load_parameters(sim_path)
    
    # Calculate soma firing rate (convert ms to seconds)
    firing_rate = len(spks[0][:]) / (params.h_tstop / 1000)
    soma_firing_rates.append(firing_rate)
    
    # Instead of rhythmic depths, record morphology and seed
    morphologies.append(params.morphology_name)
    seeds.append(params.numpy_random_state)  # Assumes params contains a seed attribute

# Add the computed columns to spike_table
spike_table['soma_firing_rate'] = soma_firing_rates
spike_table['morphology'] = morphologies
spike_table['seed'] = seeds

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# --- 1. Grouping by morphology, seed, and Segment_Type ---
grouped_stats = spike_table.groupby(
    ['morphology', 'seed', 'Segment_Type']
)[['Total_NMDA_Spikes_per_micron', 'Total_NA_Spikes_per_micron', 'Total_CA_Spikes_per_micron', 'soma_firing_rate']].agg(['mean', 'std'])

# Flatten the multi-index columns (e.g. Total_NMDA_Spikes_mean)
grouped_stats.columns = ['_'.join(col).strip() for col in grouped_stats.columns.values]
grouped_stats = grouped_stats.reset_index()

print(grouped_stats.head())

# --- 2. Plotting spike metrics as a function of morphology and seed ---

# List of spike types and corresponding titles
spike_types = ['Total_NMDA_Spikes_per_micron', 'Total_NA_Spikes_per_micron', 'Total_CA_Spikes_per_micron']
titles = ['NMDA Spikes', 'NA Spikes', 'CA Spikes']

# Loop over each spike type and each segment type for heatmap plots (mean and std)
for spike_type, title in zip(spike_types, titles):
    for segment_type in grouped_stats['Segment_Type'].unique():
        # Subset data for the current segment type
        subset = grouped_stats[grouped_stats['Segment_Type'] == segment_type]
        
        # Pivot: rows = morphology, columns = seed
        pivot_mean = subset.pivot(index='morphology', 
                                  columns='seed', 
                                  values=f'{spike_type}_mean')
        pivot_std = subset.pivot(index='morphology', 
                                 columns='seed', 
                                 values=f'{spike_type}_std')
        
        # Create a figure with two subplots for mean and std
        fig, axes = plt.subplots(1, 2, figsize=(12, 5))
        
        sns.heatmap(pivot_mean, ax=axes[0], cmap="viridis", annot=True, fmt=".3e")
        axes[0].set_title(f'{title} Mean ({segment_type})')
        axes[0].set_xlabel('Seed')
        axes[0].set_ylabel('Morphology')
        
        sns.heatmap(pivot_std, ax=axes[1], cmap="magma", annot=True, fmt=".3e")
        axes[1].set_title(f'{title} Std ({segment_type})')
        axes[1].set_xlabel('Seed')
        axes[1].set_ylabel('Morphology')
        
        plt.tight_layout()
        plt.show()

# --- 3. Plotting Soma Firing Rate similarly ---
for segment_type in grouped_stats['Segment_Type'].unique():
    subset = grouped_stats[grouped_stats['Segment_Type'] == segment_type]
    pivot_mean = subset.pivot(index='morphology', columns='seed', values='soma_firing_rate_mean')
    pivot_std = subset.pivot(index='morphology', columns='seed', values='soma_firing_rate_std')
    
    fig, axes = plt.subplots(1, 2, figsize=(12, 5))
    
    sns.heatmap(pivot_mean, ax=axes[0], cmap="viridis", annot=True, fmt=".1f")
    axes[0].set_title(f'Soma Firing Rate Mean ({segment_type})')
    axes[0].set_xlabel('Seed')
    axes[0].set_ylabel('Morphology')
    
    sns.heatmap(pivot_std, ax=axes[1], cmap="magma", annot=True, fmt=".1f")
    axes[1].set_title(f'Soma Firing Rate Std ({segment_type})')
    axes[1].set_xlabel('Seed')
    axes[1].set_ylabel('Morphology')
    
    plt.tight_layout()
    plt.show()
# Out:
#   morphology       seed Segment_Type  Total_NMDA_Spikes_per_micron_mean  \
# 0    Complex       5000         apic                           0.272185
# 1    Complex       5000         dend                           0.494634
# 2    Complex    4444444         apic                           0.207945
# 3    Complex    4444444         dend                           0.341697
# 4    Complex  123456789         apic                           0.248706
#
#    Total_NMDA_Spikes_per_micron_std  Total_NA_Spikes_per_micron_mean  \
# 0                               NaN                         0.417745
# 1                               NaN                         0.390787
# 2                               NaN                         0.518606
# 3                               NaN                         0.710374
# 4                               NaN                         0.462820
#
#    Total_NA_Spikes_per_micron_std  Total_CA_Spikes_per_micron_mean  \
# 0                             NaN                         0.005161
# 1                             NaN                         0.000000
# 2                             NaN                         0.006075
# 3                             NaN                         0.000000
# 4                             NaN                         0.010644
#
#    Total_CA_Spikes_per_micron_std  soma_firing_rate_mean  soma_firing_rate_std
# 0                             NaN                    3.3                   NaN
# 1                             NaN                    3.3                   NaN
# 2                             NaN                    0.2                   NaN
# 3                             NaN                    0.2                   NaN
# 4                             NaN                    3.3                   NaN
# /home/drfrbc/miniconda3/envs/sim_env/lib/python3.10/site-packages/seaborn/matrix.py:202: RuntimeWarning: All-NaN slice encountered
#   vmin = np.nanmin(calc_data)
# /home/drfrbc/miniconda3/envs/sim_env/lib/python3.10/site-packages/seaborn/matrix.py:207: RuntimeWarning: All-NaN slice encountered
#   vmax = np.nanmax(calc_data)
# /home/drfrbc/miniconda3/envs/sim_env/lib/python3.10/site-packages/seaborn/matrix.py:202: RuntimeWarning: All-NaN slice encountered
#   vmin = np.nanmin(calc_data)
# /home/drfrbc/miniconda3/envs/sim_env/lib/python3.10/site-packages/seaborn/matrix.py:207: RuntimeWarning: All-NaN slice encountered
#   vmax = np.nanmax(calc_data)
# /home/drfrbc/miniconda3/envs/sim_env/lib/python3.10/site-packages/seaborn/matrix.py:202: RuntimeWarning: All-NaN slice encountered
#   vmin = np.nanmin(calc_data)
# /home/drfrbc/miniconda3/envs/sim_env/lib/python3.10/site-packages/seaborn/matrix.py:207: RuntimeWarning: All-NaN slice encountered
#   vmax = np.nanmax(calc_data)
# /home/drfrbc/miniconda3/envs/sim_env/lib/python3.10/site-packages/seaborn/matrix.py:202: RuntimeWarning: All-NaN slice encountered
#   vmin = np.nanmin(calc_data)
# /home/drfrbc/miniconda3/envs/sim_env/lib/python3.10/site-packages/seaborn/matrix.py:207: RuntimeWarning: All-NaN slice encountered
#   vmax = np.nanmax(calc_data)
# /home/drfrbc/miniconda3/envs/sim_env/lib/python3.10/site-packages/seaborn/matrix.py:202: RuntimeWarning: All-NaN slice encountered
#   vmin = np.nanmin(calc_data)
# /home/drfrbc/miniconda3/envs/sim_env/lib/python3.10/site-packages/seaborn/matrix.py:207: RuntimeWarning: All-NaN slice encountered
#   vmax = np.nanmax(calc_data)
# /home/drfrbc/miniconda3/envs/sim_env/lib/python3.10/site-packages/seaborn/matrix.py:202: RuntimeWarning: All-NaN slice encountered
#   vmin = np.nanmin(calc_data)
# /home/drfrbc/miniconda3/envs/sim_env/lib/python3.10/site-packages/seaborn/matrix.py:207: RuntimeWarning: All-NaN slice encountered
#   vmax = np.nanmax(calc_data)
# /home/drfrbc/miniconda3/envs/sim_env/lib/python3.10/site-packages/seaborn/matrix.py:202: RuntimeWarning: All-NaN slice encountered
#   vmin = np.nanmin(calc_data)
# /home/drfrbc/miniconda3/envs/sim_env/lib/python3.10/site-packages/seaborn/matrix.py:207: RuntimeWarning: All-NaN slice encountered
#   vmax = np.nanmax(calc_data)
# /home/drfrbc/miniconda3/envs/sim_env/lib/python3.10/site-packages/seaborn/matrix.py:202: RuntimeWarning: All-NaN slice encountered
#   vmin = np.nanmin(calc_data)
# /home/drfrbc/miniconda3/envs/sim_env/lib/python3.10/site-packages/seaborn/matrix.py:207: RuntimeWarning: All-NaN slice encountered
#   vmax = np.nanmax(calc_data)
