# %% [markdown]
# Cleaned up version of EventHistograms.ipynb that processes multiple simulations.
#
# Uses find_events_ben.py script to identify spikes
#
# then uses event_histograms.py module to generate the figures

# %%
simulations_dir = '/home/drfrbc/Neural-Modeling/scripts/2025-03-14-08-52-all3_stas_multiple_seeds'

# %%
import sys
sys.path.append("../")
sys.path.append("../Modules/")
import Modules.event_histograms as eh

# %%
# %cd ../scripts
# Out:
# /home/drfrbc/Neural-Modeling/scripts

# %%
# Generate .csv's for dendritic events
# !python find_events_ben.py -f {simulations_dir}
# Out:
# simulations_directory: /home/drfrbc/Neural-Modeling/scripts/2025-03-14-08-52-all3_stas_multiple_seeds
# sim_directory: sta_ReduceBranches_Np5000
# sim_directory: sta_ReduceTrees_Np123456789
# sim_directory: sta_Complex_Np123456789
# sim_directory: sta_ReduceTrees_Np4444444
# sim_directory: sta_ReduceTrees_Np5000
# sim_directory: sta_ReduceBranches_Np4444444
# sim_directory: sta_Complex_Np4444444
# sim_directory: sta_Complex_Np5000
# sim_directory: sta_ReduceBranches_Np123456789

# %%
# !python ../Modules/event_histograms.py -f {simulations_dir}
# Out:
# simulations_directory: /home/drfrbc/Neural-Modeling/scripts/2025-03-14-08-52-all3_stas_multiple_seeds
# sim_directory: sta_ReduceBranches_Np5000
# Warning: no DISPLAY environment variable.
# --No graphics will be displayed.
# Retry 1/1000 failed: Trace length is 14 not 20, retrying...
# Retry 2/1000 failed: Trace length is 14 not 20, retrying...
# Retry 3/1000 failed: Trace length is 14 not 20, retrying...
# Retry 4/1000 failed: Trace length is 14 not 20, retrying...
# Retry 5/1000 failed: Trace length is 14 not 20, retrying...
# Retry 6/1000 failed: Trace length is 14 not 20, retrying...
# Retry 7/1000 failed: Trace length is 14 not 20, retrying...
# Retry 8/1000 failed: Trace length is 14 not 20, retrying...
# Retry 9/1000 failed: Trace length is 14 not 20, retrying...
# Retry 10/1000 failed: Trace length is 14 not 20, retrying...
# Retry 11/1000 failed: Trace length is 14 not 20, retrying...
# Retry 12/1000 failed: Trace length is 14 not 20, retrying...
# Retry 13/1000 failed: Trace length is 14 not 20, retrying...
# Retry 14/1000 failed: Trace length is 14 not 20, retrying...
# Retry 15/1000 failed: Trace length is 14 not 20, retrying...
# Retry 16/1000 failed: Trace length is 14 not 20, retrying...
# Retry 17/1000 failed: Trace length is 14 not 20, retrying...
# Retry 18/1000 failed: Trace length is 14 not 20, retrying...
# Retry 19/1000 failed: Trace length is 14 not 20, retrying...
# Retry 20/1000 failed: Trace length is 14 not 20, retrying...
# Retry 21/1000 failed: Trace length is 14 not 20, retrying...
# Retry 22/1000 failed: Trace length is 14 not 20, retrying...
# Retry 23/1000 failed: Trace length is 14 not 20, retrying...
# Retry 24/1000 failed: Trace length is 14 not 20, retrying...
# Retry 25/1000 failed: Trace length is 14 not 20, retrying...
# Retry 26/1000 failed: Trace length is 14 not 20, retrying...
# Retry 27/1000 failed: Trace length is 14 not 20, retrying...
# Retry 28/1000 failed: Trace length is 14 not 20, retrying...
# Retry 29/1000 failed: Trace length is 14 not 20, retrying...
# Retry 30/1000 failed: Trace length is 14 not 20, retrying...
# Retry 31/1000 failed: Trace length is 14 not 20, retrying...
# Retry 32/1000 failed: Trace length is 14 not 20, retrying...
# Retry 33/1000 failed: Trace length is 14 not 20, retrying...
# Retry 34/1000 failed: Trace length is 14 not 20, retrying...
# Retry 35/1000 failed: Trace length is 14 not 20, retrying...
# Retry 36/1000 failed: Trace length is 14 not 20, retrying...
# Retry 37/1000 failed: Trace length is 14 not 20, retrying...
# Retry 38/1000 failed: Trace length is 14 not 20, retrying...
# Retry 39/1000 failed: Trace length is 14 not 20, retrying...
# Retry 40/1000 failed: Trace length is 14 not 20, retrying...
# Retry 41/1000 failed: Trace length is 14 not 20, retrying...
# Retry 42/1000 failed: Trace length is 14 not 20, retrying...
# Retry 43/1000 failed: Trace length is 14 not 20, retrying...
# Retry 44/1000 failed: Trace length is 14 not 20, retrying...
# Retry 45/1000 failed: Trace length is 14 not 20, retrying...
# Retry 46/1000 failed: Trace length is 14 not 20, retrying...
# Retry 47/1000 failed: Trace length is 14 not 20, retrying...
# Retry 48/1000 failed: Trace length is 14 not 20, retrying...
# Retry 49/1000 failed: Trace length is 14 not 20, retrying...
# Retry 50/1000 failed: Trace length is 14 not 20, retrying...
# Retry 51/1000 failed: Trace length is 14 not 20, retrying...
# Retry 52/1000 failed: Trace length is 14 not 20, retrying...
# Retry 53/1000 failed: Trace length is 14 not 20, retrying...
# Retry 54/1000 failed: Trace length is 14 not 20, retrying...
# Retry 55/1000 failed: Trace length is 14 not 20, retrying...
# Retry 56/1000 failed: Trace length is 14 not 20, retrying...
# Retry 57/1000 failed: Trace length is 14 not 20, retrying...
# Retry 58/1000 failed: Trace length is 14 not 20, retrying...
# Retry 59/1000 failed: Trace length is 14 not 20, retrying...
# Retry 60/1000 failed: Trace length is 14 not 20, retrying...
# Retry 61/1000 failed: Trace length is 14 not 20, retrying...
# Retry 62/1000 failed: Trace length is 14 not 20, retrying...
# Retry 63/1000 failed: Trace length is 14 not 20, retrying...
# Retry 64/1000 failed: Trace length is 14 not 20, retrying...
# Retry 65/1000 failed: Trace length is 14 not 20, retrying...
# Retry 66/1000 failed: Trace length is 14 not 20, retrying...
# Retry 67/1000 failed: Trace length is 14 not 20, retrying...
# Retry 68/1000 failed: Trace length is 14 not 20, retrying...
# Retry 69/1000 failed: Trace length is 14 not 20, retrying...
# Retry 70/1000 failed: Trace length is 14 not 20, retrying...
# Retry 71/1000 failed: Trace length is 14 not 20, retrying...
# Retry 72/1000 failed: Trace length is 14 not 20, retrying...
# Retry 73/1000 failed: Trace length is 14 not 20, retrying...
# Retry 74/1000 failed: Trace length is 14 not 20, retrying...
# Retry 75/1000 failed: Trace length is 14 not 20, retrying...
# Retry 76/1000 failed: Trace length is 14 not 20, retrying...
# Retry 77/1000 failed: Trace length is 14 not 20, retrying...
# Retry 78/1000 failed: Trace length is 14 not 20, retrying...
# Retry 79/1000 failed: Trace length is 14 not 20, retrying...
# Retry 80/1000 failed: Trace length is 14 not 20, retrying...
# Retry 81/1000 failed: Trace length is 14 not 20, retrying...
# Retry 82/1000 failed: Trace length is 14 not 20, retrying...
# Retry 83/1000 failed: Trace length is 14 not 20, retrying...
# Retry 84/1000 failed: Trace length is 14 not 20, retrying...
# Retry 85/1000 failed: Trace length is 14 not 20, retrying...
# Retry 86/1000 failed: Trace length is 14 not 20, retrying...
# Retry 87/1000 failed: Trace length is 14 not 20, retrying...
# Retry 88/1000 failed: Trace length is 14 not 20, retrying...
# Retry 89/1000 failed: Trace length is 14 not 20, retrying...
# Retry 90/1000 failed: Trace length is 14 not 20, retrying...
# Retry 91/1000 failed: Trace length is 14 not 20, retrying...
# Retry 92/1000 failed: Trace length is 14 not 20, retrying...
# Retry 93/1000 failed: Trace length is 14 not 20, retrying...
# Retry 94/1000 failed: Trace length is 14 not 20, retrying...
# Retry 95/1000 failed: Trace length is 14 not 20, retrying...
# Retry 96/1000 failed: Trace length is 14 not 20, retrying...
# Retry 97/1000 failed: Trace length is 14 not 20, retrying...
# Retry 98/1000 failed: Trace length is 14 not 20, retrying...
# Retry 99/1000 failed: Trace length is 14 not 20, retrying...
# Retry 100/1000 failed: Trace length is 14 not 20, retrying...
# Retry 101/1000 failed: Trace length is 14 not 20, retrying...
# Retry 102/1000 failed: Trace length is 14 not 20, retrying...
# Retry 103/1000 failed: Trace length is 14 not 20, retrying...
# Retry 104/1000 failed: Trace length is 14 not 20, retrying...
# Retry 105/1000 failed: Trace length is 14 not 20, retrying...
# Retry 106/1000 failed: Trace length is 14 not 20, retrying...
# Retry 107/1000 failed: Trace length is 14 not 20, retrying...
# Retry 108/1000 failed: Trace length is 14 not 20, retrying...
# Retry 109/1000 failed: Trace length is 14 not 20, retrying...
# Retry 110/1000 failed: Trace length is 14 not 20, retrying...
# Retry 111/1000 failed: Trace length is 14 not 20, retrying...
# Retry 112/1000 failed: Trace length is 14 not 20, retrying...
# Retry 113/1000 failed: Trace length is 14 not 20, retrying...
# Retry 114/1000 failed: Trace length is 14 not 20, retrying...
# Retry 115/1000 failed: Trace length is 14 not 20, retrying...
# Retry 116/1000 failed: Trace length is 14 not 20, retrying...
# Retry 117/1000 failed: Trace length is 14 not 20, retrying...
# Retry 118/1000 failed: Trace length is 14 not 20, retrying...
# Retry 119/1000 failed: Trace length is 14 not 20, retrying...
# Retry 120/1000 failed: Trace length is 14 not 20, retrying...
# Retry 121/1000 failed: Trace length is 14 not 20, retrying...
# Retry 122/1000 failed: Trace length is 14 not 20, retrying...
# Retry 123/1000 failed: Trace length is 14 not 20, retrying...
# Retry 124/1000 failed: Trace length is 14 not 20, retrying...
# Retry 125/1000 failed: Trace length is 14 not 20, retrying...
# Retry 126/1000 failed: Trace length is 14 not 20, retrying...
# Retry 127/1000 failed: Trace length is 14 not 20, retrying...
# Retry 128/1000 failed: Trace length is 14 not 20, retrying...
# Retry 129/1000 failed: Trace length is 14 not 20, retrying...
# Retry 130/1000 failed: Trace length is 14 not 20, retrying...
# Retry 131/1000 failed: Trace length is 14 not 20, retrying...
# Retry 132/1000 failed: Trace length is 14 not 20, retrying...
# Retry 133/1000 failed: Trace length is 14 not 20, retrying...
# Retry 134/1000 failed: Trace length is 14 not 20, retrying...
# Retry 135/1000 failed: Trace length is 14 not 20, retrying...
# Retry 136/1000 failed: Trace length is 14 not 20, retrying...
# Retry 137/1000 failed: Trace length is 14 not 20, retrying...
# Retry 138/1000 failed: Trace length is 14 not 20, retrying...
# Retry 139/1000 failed: Trace length is 14 not 20, retrying...
# Retry 140/1000 failed: Trace length is 14 not 20, retrying...
# Retry 141/1000 failed: Trace length is 14 not 20, retrying...
# Retry 142/1000 failed: Trace length is 14 not 20, retrying...
# Retry 143/1000 failed: Trace length is 14 not 20, retrying...
# Retry 144/1000 failed: Trace length is 14 not 20, retrying...
# Retry 145/1000 failed: Trace length is 14 not 20, retrying...
# Retry 146/1000 failed: Trace length is 14 not 20, retrying...
# Retry 147/1000 failed: Trace length is 14 not 20, retrying...
# Retry 148/1000 failed: Trace length is 14 not 20, retrying...
# Retry 149/1000 failed: Trace length is 14 not 20, retrying...
# Retry 150/1000 failed: Trace length is 14 not 20, retrying...
# Retry 151/1000 failed: Trace length is 14 not 20, retrying...
# Retry 152/1000 failed: Trace length is 14 not 20, retrying...
# Retry 153/1000 failed: Trace length is 14 not 20, retrying...
# Retry 154/1000 failed: Trace length is 14 not 20, retrying...
# Retry 155/1000 failed: Trace length is 14 not 20, retrying...
# Retry 156/1000 failed: Trace length is 14 not 20, retrying...
# Retry 157/1000 failed: Trace length is 14 not 20, retrying...
# Retry 158/1000 failed: Trace length is 14 not 20, retrying...
# Retry 159/1000 failed: Trace length is 14 not 20, retrying...
# Retry 160/1000 failed: Trace length is 14 not 20, retrying...
# Retry 161/1000 failed: Trace length is 14 not 20, retrying...
# Retry 162/1000 failed: Trace length is 14 not 20, retrying...
# Retry 163/1000 failed: Trace length is 14 not 20, retrying...
# Figure(600x600)
# Figure(600x600)
# Figure(200x500)
# Figure(600x600)
# Figure(600x600)
# Figure(200x500)
# Figure(600x600)
# sim_directory: sta_ReduceTrees_Np123456789
# /home/drfrbc/Neural-Modeling/scripts/../Modules/event_histograms.py:349: RuntimeWarning: invalid value encountered in divide
#   plt.imshow(100 * ca_df_imhist / ca_df_imhist.sum(), origin = 'lower')
# Figure(600x600)
# Figure(200x500)
# Figure(600x600)
# Figure(600x600)
# Figure(200x500)
# Figure(600x600)
# Figure(600x600)
# Figure(200x500)
# Figure(600x600)
# sim_directory: sta_Complex_Np123456789
# /home/drfrbc/Neural-Modeling/scripts/../Modules/event_histograms.py:60: DtypeWarning: Columns (33) have mixed types. Specify dtype option on import or set low_memory=False.
#   na_df = pd.read_csv(os.path.join(sim_directory,'na.csv'))
# /home/drfrbc/Neural-Modeling/scripts/../Modules/event_histograms.py:62: DtypeWarning: Columns (33) have mixed types. Specify dtype option on import or set low_memory=False.
#   nmda_df = pd.read_csv(os.path.join(sim_directory,'nmda.csv'))
# Figure(600x600)
# Figure(200x500)
# Figure(600x600)
# Figure(600x600)
# Figure(200x500)
# Figure(600x600)
# Figure(600x600)
# Figure(200x500)
# Figure(600x600)
# sim_directory: sta_ReduceTrees_Np4444444
# /home/drfrbc/Neural-Modeling/scripts/../Modules/event_histograms.py:349: RuntimeWarning: invalid value encountered in divide
#   plt.imshow(100 * ca_df_imhist / ca_df_imhist.sum(), origin = 'lower')
# Figure(600x600)
# Figure(200x500)
# Figure(600x600)
# Figure(600x600)
# Figure(200x500)
# Figure(600x600)
# Figure(600x600)
# Figure(200x500)
# Figure(600x600)
# sim_directory: sta_ReduceTrees_Np5000
# /home/drfrbc/Neural-Modeling/scripts/../Modules/event_histograms.py:349: RuntimeWarning: invalid value encountered in divide
#   plt.imshow(100 * ca_df_imhist / ca_df_imhist.sum(), origin = 'lower')
# Figure(600x600)
# Figure(200x500)
# Figure(600x600)
# Figure(600x600)
# Figure(200x500)
# Figure(600x600)
# Figure(600x600)
# Figure(200x500)
# Figure(600x600)
# sim_directory: sta_ReduceBranches_Np4444444
# /home/drfrbc/Neural-Modeling/scripts/../Modules/event_histograms.py:349: RuntimeWarning: invalid value encountered in divide
#   plt.imshow(100 * ca_df_imhist / ca_df_imhist.sum(), origin = 'lower')
# Figure(600x600)
# Figure(200x500)
# Figure(600x600)
# Figure(600x600)
# Figure(200x500)
# Figure(600x600)
# Figure(600x600)
# Figure(200x500)
# Figure(600x600)
# sim_directory: sta_Complex_Np4444444
# /home/drfrbc/Neural-Modeling/scripts/../Modules/event_histograms.py:60: DtypeWarning: Columns (33) have mixed types. Specify dtype option on import or set low_memory=False.
#   na_df = pd.read_csv(os.path.join(sim_directory,'na.csv'))
# /home/drfrbc/Neural-Modeling/scripts/../Modules/event_histograms.py:62: DtypeWarning: Columns (33) have mixed types. Specify dtype option on import or set low_memory=False.
#   nmda_df = pd.read_csv(os.path.join(sim_directory,'nmda.csv'))
# Figure(600x600)
# Figure(200x500)
# Figure(600x600)
# Figure(600x600)
# Figure(200x500)
# Figure(600x600)
# Figure(600x600)
# Figure(200x500)
# Figure(600x600)
# sim_directory: sta_Complex_Np5000
# /home/drfrbc/Neural-Modeling/scripts/../Modules/event_histograms.py:60: DtypeWarning: Columns (33) have mixed types. Specify dtype option on import or set low_memory=False.
#   na_df = pd.read_csv(os.path.join(sim_directory,'na.csv'))
# /home/drfrbc/Neural-Modeling/scripts/../Modules/event_histograms.py:62: DtypeWarning: Columns (33) have mixed types. Specify dtype option on import or set low_memory=False.
#   nmda_df = pd.read_csv(os.path.join(sim_directory,'nmda.csv'))
# Figure(600x600)
# Figure(200x500)
# Figure(600x600)
# Figure(600x600)
# Figure(200x500)
# Figure(600x600)
# Figure(600x600)
# Figure(200x500)
# Figure(600x600)
# sim_directory: sta_ReduceBranches_Np123456789
# Figure(600x600)
# Figure(200x500)
# Figure(600x600)
# Figure(600x600)
# Figure(200x500)
# Figure(600x600)
# Figure(600x600)
# Figure(200x500)
# Figure(600x600)
