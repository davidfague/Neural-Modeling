# %%
import sys
sys.path.append('..')
sys.path.append('../Modules')

# %%
from Modules.accuracy_metrics import compare_STAs_between_simulations

# %%
sim_dirs = [
    "/home/drfrbc/Neural-Modeling/simulations/2025-12-23-13-34-test_save_sta/testing_Complex_Np5000",
    "/home/drfrbc/Neural-Modeling/simulations/2025-12-23-13-34-test_save_sta/testing_Complex_Np5000"
]

# %%
compare_STAs_between_simulations.compare_sims(sim_dirs)
# Out:
#                                                 sim1  \
# 0  /home/drfrbc/Neural-Modeling/simulations/2025-...
#
#                                                 sim2  pois_ca_sta__na_a  \
# 0  /home/drfrbc/Neural-Modeling/simulations/2025-...                0.0
#
#    pois_ca_sta__na_sta__apic  pois_ca_sta__na_sta__dend  pois_ca_sta__nmda_a  \
# 0                        0.0                        NaN                  0.0
#
#    pois_ca_sta__nmda_sta__apic  pois_ca_sta__nmda_sta__dend  \
# 0                          0.0                          0.0
#
#    pois_canmda_sta__na_a  pois_canmda_sta__na_b  ...  pois_sta__ca_a  \
# 0                    0.0                    NaN  ...             0.0
#
#    pois_sta__ca_sta__apic  pois_sta__na_a  pois_sta__na_b  \
# 0                     0.0             0.0             0.0
#
#    pois_sta__na_sta__apic  pois_sta__na_sta__dend  pois_sta__nmda_a  \
# 0                     0.0                     0.0               0.0
#
# ...
