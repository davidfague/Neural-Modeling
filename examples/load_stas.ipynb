# %%
import sys
sys.path.append('..')
sys.path.append('../Modules')

# %%
from Modules.dendritic_spikes.drew_load_sta import load_sta_npz
import os
sim_dir = "/home/drfrbc/Neural-Modeling/examples/example_simulations/has_sta_saved"
sta_file = os.path.join(sim_dir, "dspike_sta.npz")
print(load_sta_npz(sta_file))
# Out:
# {'pois_sta__ca_sta__apic': array([[  5.1993876 ,   6.490045  ,   6.751625  , ...,  -7.5899835 ,
#          -5.771026  ,  -5.771026  ],
#        [  7.224239  ,  14.881976  ,  19.013811  , ...,   2.6668186 ,
#          -0.43679342,  -4.280527  ],
#        [ 14.311843  ,  14.429568  ,  16.936684  , ...,  -6.98461   ,
#          -2.874903  ,   0.37137407],
#        ...,
#        [ -9.444898  ,  23.128448  ,  23.128448  , ..., -53.236065  ,
#         -53.35386   , -53.35386   ],
#        [-17.817226  ,   9.577033  ,   9.577033  , ..., -46.1671    ,
#         -46.1671    , -46.1671    ],
#        [-18.059652  ,  26.839169  ,  26.839169  , ..., -15.824916  ,
#         -15.824916  , -15.824916  ]], dtype=float32), 'pois_sta__nmda_sta__apic': array([[   9.902187 ,    7.6658053,    4.624398 , ...,   -2.0184205,
#           -7.4074073,   -7.4074073],
#        [   1.7501018,    2.0311794,    2.0311794, ...,   -8.99936  ,
#           -8.99936  ,  -13.056683 ],
# ...

# %%
d = load_sta_npz(sta_file)
apic_nmda = d["pois_canmda_sta__nmda_sta__apic"]   # (10, 200)
dend_nmda = d["pois_canmda_sta__nmda_sta__dend"]   # (10, 200)
nmda_a    = d["pois_canmda_sta__nmda_a"]
